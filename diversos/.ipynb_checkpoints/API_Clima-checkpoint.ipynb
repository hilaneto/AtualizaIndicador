# %%
import requests

url = "https://wis2bra.inmet.gov.br/oapi/collections/stations/items"

parametros = {"f": "json", "limit": 10}
resposta = requests.get(url, params=parametros, timeout=30)
resposta.raise_for_status()

dados = resposta.json() #["EURBRL"]

# print("Compra:", dolar["bid"])

print(dados)

# %%
import requests

url = "https://wis2bra.inmet.gov.br/oapi/collections/stations/items"

parametros = {"f": "json", "limit": 10}

resposta = requests.get(url, params=parametros, timeout=30)

resposta.raise_for_status()

dados = resposta.json()

print(dados.keys())

# %%
for estacao in dados["features"]:
    print(estacao["properties"])

# %%
url = ("https://wis2bra.inmet.gov.br/oapi/collections/stations/items/0-20000-0-83781")

resposta = requests.get(url, params={"f": "json"}, timeout=30)
resposta.raise_for_status()
estacao = resposta.json()

print(estacao)

# %%
import requests

url = ("https://wis2bra.inmet.gov.br/oapi/collections/urn:wmo:md:br-inmet:synop/items")

parametros = {"f": "json", "limit": 100}

resposta = requests.get(url, params=parametros, timeout=30)

resposta.raise_for_status()

dados = resposta.json()

print(dados.keys())

# %%
for obs in dados["features"]:

    prop = obs["properties"]

    if prop["name"] == "air_temperature":

        print(
            prop["wigos_station_identifier"],
            prop["value"],
            prop["units"],
            prop["phenomenonTime"]
        )

# %%
properties["wigos_station_identifier"] == "0-20000-0-83781"

# %%
for obs in dados["features"]:
    print(obs["properties"])

# %%
import requests
from datetime import datetime, timezone, timedelta

url = (
    "https://wis2bra.inmet.gov.br/oapi/collections/"
    "urn:wmo:md:br-inmet:synop/items"
)

agora = datetime.now(timezone.utc)
inicio = agora - timedelta(hours=2)

parametros = {
    "f": "json",
    "limit": 100,
    "datetime": f"{inicio.isoformat()}/{agora.isoformat()}"
}

resposta = requests.get(
    url,
    params=parametros,
    timeout=30
)

resposta.raise_for_status()

dados = resposta.json()

for obs in dados["features"]:
    prop = obs["properties"]

    if prop["name"] == "air_temperature":
        print(
            prop["wigos_station_identifier"],
            prop["value"],
            prop["units"],
            prop["phenomenonTime"]
        )

# %%
url_estacoes = "https://wis2bra.inmet.gov.br/oapi/collections/stations/items"

parametros_estacoes = {
    "f": "json",
    "limit": 1000
}

resposta = requests.get(
    url_estacoes,
    params=parametros_estacoes,
    timeout=30
)

resposta.raise_for_status()

dados_estacoes = resposta.json()

estacoes = {}

for estacao in dados_estacoes["features"]:

    prop = estacao["properties"]

    estacoes[prop["wigos_station_identifier"]] = {
        "nome": prop["name"],
        "status": prop["status"],
        "coordenadas": estacao["geometry"]["coordinates"]
    }

# %%
for obs in dados["features"]:

    prop = obs["properties"]

    if prop["name"] == "air_temperature":

        wigos = prop["wigos_station_identifier"]

        if wigos in estacoes:

            print(
                estacoes[wigos]["nome"],
                prop["value"],
                prop["units"],
                prop["phenomenonTime"]
            )

# %%
import requests

url = "https://wis2bra.inmet.gov.br/oapi/collections/stations/items"

parametros = {"f": "json", "limit": 1000}
resposta = requests.get(url, params=parametros, timeout=30)
resposta.raise_for_status()

dados = resposta.json()
dados

# %%
estacoes = []

for registro in dados["features"]:

    propriedades = registro["properties"]
    coordenadas = registro["geometry"]["coordinates"]

    estacao = {
        "wigos": propriedades["wigos_station_identifier"],
        "nome": propriedades["name"],
        "longitude": coordenadas[0],
        "latitude": coordenadas[1],
        "altitude": coordenadas[2],
        "status": propriedades["status"]
    }

    estacoes.append(estacao)

# %%
for estacao in estacoes:
    print(estacao)

# %%
capitais = ['Brasília','Goiânia','Cuiabá','Campo Grande','Maceió','Salvador','Fortaleza','São Luís','João Pessoa','Recife','Teresina','Natal','Aracaju','Rio Branco','Macapá','Manaus','Belém','Porto Velho','Boa Vista','Palmas','Vitória','Belo Horizonte','Rio de Janeiro','São Paulo','Curitiba','Porto Alegre','Florianópolis']            

for estacao in estacoes:
    for aa in capitais:
        if aa.upper() in estacao["nome"]:
            print(estacao)

# %%
capitais = [
    'Brasília', 'Goiânia', 'Cuiabá', 'Campo Grande',
    'Maceió', 'Salvador', 'Fortaleza', 'São Luís',
    'João Pessoa', 'Recife', 'Teresina', 'Natal',
    'Aracaju', 'Rio Branco', 'Macapá', 'Manaus',
    'Belém', 'Porto Velho', 'Boa Vista', 'Palmas',
    'Vitória', 'Belo Horizonte', 'Rio de Janeiro',
    'São Paulo', 'Curitiba', 'Porto Alegre',
    'Florianópolis'
]

for estacao in estacoes:
    nome = estacao["nome"].upper()
    for capital in capitais:
        if capital.upper() in nome:
            print(estacao["nome"], estacao["wigos"])

# %%
for obs in dados["features"]:

    prop = obs["properties"]

    if prop["name"] == "air_temperature":

        wigos = prop["wigos_station_identifier"]

        if wigos in estacoes:

            print(
                estacoes[wigos]["nome"],
                prop["value"],
                prop["units"],
                prop["phenomenonTime"]
            )

# %%
capitais = ['BRASILIA', 'GOIANIA', 'CUIABA', 'CAMPO GRANDE',
            'MACEIO', 'SALVADOR', 'FORTALEZA', 'SAO LUIS',
            'JOAO PESSOA', 'RECIFE', 'TERESINA', 'NATAL',
            'ARACAJU', 'RIO BRANCO', 'MACAPA', 'MANAUS',
            'BELEM', 'PORTO VELHO', 'BOA VISTA', 'PALMAS',
            'VITORIA', 'BELO HORIZONTE', 'RIO DE JANEIRO',
            'SAO PAULO', 'CURITIBA', 'PORTO ALEGRE',
            'FLORIANOPOLIS'
           ]

for estacao in estacoes:
    nome = estacao["nome"].upper()

    for capital in capitais:
        if capital.upper() in nome:
            print(estacao["wigos"])

# %%
estacoes

# %%
# wigos = "0-20000-0-83781"


capitais = [
    'BRASILIA', 'GOIANIA', 'CUIABA', 'CAMPO GRANDE',
    'MACEIO', 'SALVADOR', 'FORTALEZA', 'SAO LUIS',
    'JOAO PESSOA', 'RECIFE', 'TERESINA', 'NATAL',
    'ARACAJU', 'RIO BRANCO', 'MACAPA', 'MANAUS',
    'BELEM', 'PORTO VELHO', 'BOA VISTA', 'PALMAS',
    'VITORIA', 'BELO HORIZONTE', 'RIO DE JANEIRO',
    'SAO PAULO', 'CURITIBA', 'PORTO ALEGRE',
    'FLORIANOPOLIS'
]


# ---------------------------------------------------------
# 1. Localizar estações das capitais
# ---------------------------------------------------------

estacoes_capitais = {}

for estacao in estacoes:

    nome = estacao["nome"].upper()

    for capital in capitais:

        if capital in nome:

            estacoes_capitais[estacao["wigos"]] = {
                "capital": capital,
                "nome_estacao": estacao["nome"],
                "longitude": estacao["longitude"],
                "latitude": estacao["latitude"],
                "altitude": estacao["altitude"]
            }
            
            capitais = ['BRASILIA', 'GOIANIA', 'CUIABA', 'CAMPO GRANDE',
            'MACEIO', 'SALVADOR', 'FORTALEZA', 'SAO LUIS',
            'JOAO PESSOA', 'RECIFE', 'TERESINA', 'NATAL',
            'ARACAJU', 'RIO BRANCO', 'MACAPA', 'MANAUS',
            'BELEM', 'PORTO VELHO', 'BOA VISTA', 'PALMAS',
            'VITORIA', 'BELO HORIZONTE', 'RIO DE JANEIRO',
            'SAO PAULO', 'CURITIBA', 'PORTO ALEGRE',
            'FLORIANOPOLIS'
           ]

for estacao in estacoes:
    nome = estacao["nome"].upper()
    for capital in capitais:
        if capital in nome:
            for estacao in estacoes:
                if estacao["wigos"] == estacao["wigos"]:
                    print(estacao)

# %% [markdown]
# ## ------------------ Aqui --------------------------

# %%
import requests

url = "https://wis2bra.inmet.gov.br/oapi/collections/stations/items"

parametros = {"f": "json", "limit": 10}
resposta = requests.get(url, params=parametros, timeout=30)
resposta.raise_for_status()

dados = resposta.json() #["EURBRL"]

# %%
estacoes = []

for registro in dados["features"]:

    propriedades = registro["properties"]
    coordenadas = registro["geometry"]["coordinates"]

    estacao = {
        "wigos": propriedades["wigos_station_identifier"],
        "nome": propriedades["name"],
        "longitude": coordenadas[0],
        "latitude": coordenadas[1],
        "altitude": coordenadas[2],
        "status": propriedades["status"]
    }

    estacoes.append(estacao)

# %%
import requests

url = "https://wis2bra.inmet.gov.br/oapi/collections/stations/items"

parametros = {"f": "json", "limit": 1000}
resposta = requests.get(url, params=parametros, timeout=30)
resposta.raise_for_status()

dados = resposta.json()
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'id': '0-76-0-1200351000000456',
#    'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-72.786667, -8.95, 220.98]},
#    'properties': {'name': 'MARECHAL THAUMATURGO',
#     'wigos_station_identifier': '0-76-0-1200351000000456',
#     'traditional_station_identifier': '81922',
#     'barometer_height': 222.48,
#     'facility_type': 'landFixed',
#     'territory_name': 'BRA',
#     'wmo_region': 'southAmerica',
#     'url': 'https://oscar.wmo.int/surface/#/search/station/stationReportDetails/0-76-0-1200351000000456',
#     'topic': 'origin/a/wis2/br-inmet/data/core/weather/surface-based-observations/synop',
#     'topics': ['origin/a/wis2/br-inmet/data/core/weather/surface-based-observations/synop'],
#     'status': 'operational',
#     'id': '0-76-0-1200351000000456'}},
#   {'id': '0-76-0-1200393000000457',
#    'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-72.747778, -8.267222, 205.35]},
#    'properties': {'name': 'PORTO WALTER',
#     'wigos_station_identifier': '0-76-0-1200393000000457',
#     'traditional_station_identifier': '81921',
#     'barometer_height': 206.85,
#     'facility_type': 'landFixed',
#     'territory_name': 'BRA',
#     'wmo_region': 'southAmerica',
#     'url': 'https://oscar.wmo.int/surface/#/search/station/stationReportDetails/0-76-0-1200393000000457',
#     'topic': 'origin/a/wis2/br-inmet/data/core/weather/surface-based-observations/synop',
#     'topics': ['origin/a/wis2/br-inmet/data/core/weather/surface-based-observations/synop'],
#     'status': 'operational',
#     'id': '0-76-0-1200393000000457'}},
#   {'id': '0-76-0-1100205000000227',
#    'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-63.845833, -8.793611, 86.7]},
#    'properties': {'name': 'PORTO VELHO',
#     'wigos_station_identifier': '0-76-0-1100205000000227',
#     'traditional_station_identifier': '81932',
#     'barometer_height': 88.2,
#     'facility_type': 'landFixed',
#     'territory_name': 'BRA',
#     'wmo_region': 'southAmerica',
#     'url': 'https://oscar.wmo.int/surface/#/search/station/stationReportDetails/0-76-0-1100205000000227',
#     'topic': 'origin/a/wis2/br-inmet/data/core/weather/surface-based-observations/synop',
#     'topics': ['origin/a/wis2/br-inmet/data/core/weather/surface-based-observations/synop'],
#     'status': 'operational',
#     'id': '0-76-0-1100205000000227'}},
#   {'id': '0-76-0-1100023000000405',
#    'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-62.961944, -9.948889, 128.44]},
#    'properties': {'name': 'ARIQUEMES',
#     'wigos_station_identifier': '0-76-0-1100023000000405',
#     'traditional_station_identifier': '81970',
#     'barometer_height': 129.94,
#     'facility_type': 'landFixed',
#     'territory_name': 'BRA',
#     'wmo_region': 'southAmerica',
#     'url': 'https://oscar.wmo.int/surface/#/search/station/stationReportDetails/0-76-0-1100023000000405',
#     'topic': 'origin/a/wis2/br-inmet/data/core/weather/surface-based-observations/synop',
#     'topics': ['origin/a/wis2/br-inmet/data/core/weather/surface-based-observations/synop'],
#     'status': 'operational',
#     'id': '0-76-0-1100023000000405'}},
#   {'id': '0-76-0-1303536000000343',
#    'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-60.025833, -2.056667, 60.99]},
#    'properties': {'name': 'PRESIDENTE FIGUEIREDO',
#     'wigos_station_identifier': '0-76-0-1303536000000343',
#     'traditional_station_identifier': '81699',
#     'barometer_height': 62.49,
#     'facility_type': 'landFixed',
#     'territory_name': 'BRA',
#     'wmo_region': 'southAmerica',
#     'url': 'https://oscar.wmo.int/surface/#/search/station/stationReportDetails/0-76-0-1303536000000343',
#     'topic': 'origin/a/wis2/br-inmet/data/core/weather/surface-based-observations/synop',
#     'topics': ['origin/a/wis2/br-inmet/data/core/weather/surface-based-observations/synop'],
#     'status': 'operational',
#     'id': '0-76-0-1303536000000343'}},
#   {'id': '0-76-0-1303536000000390',
#    'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-59.600556, -2.633611, 112.84]},
#    'properties': {'name': 'RIO URUBU',
#     'wigos_station_identifier': '0-76-0-1303536000000390',
#     'traditional_station_identifier': '81700',
#     'barometer_height': 114.34,
#     'facility_type': 'landFixed',
#     'territory_name': 'BRA',
#     'wmo_region': 'southAmerica',
#     'url': 'https://oscar.wmo.int/surface/#/search/station/stationReportDetails/0-76-0-1303536000000390',
#     'topic': 'origin/a/wis2/br-inmet/data/core/weather/surface-based-observations/synop',
#     'topics': ['origin/a/wis2/br-inmet/data/core/weather/surface-based-observations/synop'],
#     'status': 'operational',
#     'id': '0-76-0-1303536000000390'}},
#   {'id': '0-76-0-1302405000000412',
#    'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-64.788611, -7.260556, 61.91]},
#    'properties': {'name': 'LABREA',
#     'wigos_station_identifier': '0-76-0-1302405000000412',
#     'traditional_station_identifier': '81888',
#     'barometer_height': 63.41,
#     'facility_type': 'landFixed',
#     'territory_name': 'BRA',
#     'wmo_region': 'southAmerica',
#     'url': 'https://oscar.wmo.int/surface/#/search/station/stationReportDetails/0-76-0-1302405000000412',
#     'topic': 'origin/a/wis2/br-inmet/data/core/weather/surface-based-observations/synop',
#     'topics': ['origin/a/wis2/br-inmet/data/core/weather/surface-based-observations/synop'],
#     'status': 'operational',
#     'id': '0-76-0-1302405000000412'}},
#   {'id': '0-76-0-1302900000000345',
#    'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-57.673889, -3.398889, 25.49]},
#    'properties': {'name': 'MAUES',
#     'wigos_station_identifier': '0-76-0-1302900000000345',
#     'traditional_station_identifier': '81734',
#     'barometer_height': 26.99,
#     'facility_type': 'landFixed',
#     'territory_name': 'BRA',
#     'wmo_region': 'southAmerica',
#     'url': 'https://oscar.wmo.int/surface/#/search/station/stationReportDetails/0-76-0-1302900000000345',
#     'topic': 'origin/a/wis2/br-inmet/data/core/weather/surface-based-observations/synop',
#     'topics': ['origin/a/wis2/br-inmet/data/core/weather/surface-based-observations/synop'],
#     'status': 'operational',
#     'id': '0-76-0-1302900000000345'}},
#   {'id': '0-76-0-1504455000000289',
#    'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-52.963333, -3.510833, 251.68]},
#    'properties': {'name': 'MEDICILANDIA',
#     'wigos_station_identifier': '0-76-0-1504455000000289',
#     'traditional_station_identifier': '81739',
#     'barometer_height': 253.18,
#     'facility_type': 'landFixed',
#     'territory_name': 'BRA',
#     'wmo_region': 'southAmerica',
#     'url': 'https://oscar.wmo.int/surface/#/search/station/stationReportDetails/0-76-0-1504455000000289',
#     'topic': 'origin/a/wis2/br-inmet/data/core/weather/surface-based-observations/synop',
#     'topics': ['origin/a/wis2/br-inmet/data/core/weather/surface-based-observations/synop'],
#     'status': 'operational',
#     'id': '0-76-0-1504455000000289'}},
#   {'id': '0-76-0-1502301000000473',
#    'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-47.0575, -1.734722, 79.1]},
#    'properties': {'name': 'CAPITAO POCO',
#     'wigos_station_identifier': '0-76-0-1502301000000473',
#     'traditional_station_identifier': '81684',
#     'barometer_height': 80.6,
#     'facility_type': 'landFixed',
#     'territory_name': 'BRA',
#     'wmo_region': 'southAmerica',
#     'url': 'https://oscar.wmo.int/surface/#/search/station/stationReportDetails/0-76-0-1502301000000473',
#     'topic': 'origin/a/wis2/br-inmet/data/core/weather/surface-based-observations/synop',
#     'topics': ['origin/a/wis2/br-inmet/data/core/weather/surface-based-observations/synop'],
#     'status': 'operational',
#     'id': '0-76-0-1502301000000473'}},
#   {'id': '0-76-0-1502103000000386',
#    'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-49.499722, -2.239722, 9.92]},
#    'properties': {'name': 'CAMETA',
#     'wigos_station_identifier': '0-76-0-1502103000000386',
#     'traditional_station_identifier': '81710',
#     'barometer_height': 11.42,
#     'facility_type': 'landFixed',
#     'territory_name': 'BRA',
#     'wmo_region': 'southAmerica',
#     'url': 'https://oscar.wmo.int/surface/#/search/station/stationReportDetails/0-76-0-1502103000000386',
#     'topic': 'origin/a/wis2/br-inmet/data/core/weather/surface-based-observations/synop',
#     'topics': ['origin/a/wis2/br-inmet/data/core/weather/surface-based-observations/synop'],
#     'status': 'operational',
#     'id': '0-76-0-1502103000000386'}},
#   {'id': '0-76-0-1504208000000449',
#    'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-49.051111, -5.366389, 116.58]},
#    'properties': {'name': 'MARABA',
#     'wigos_station_identifier': '0-76-0-1504208000000449',
#     'traditional_station_identifier': '81820',
#     'barometer_height': 118.08,
#     'facility_type': 'landFixed',
#     'territory_name': 'BRA',
#     'wmo_region': 'southAmerica',
#     'url': 'https://oscar.wmo.int/surface/#/search/station/stationReportDetails/0-76-0-1504208000000449',
#     'topic': 'origin/a/wis2/br-inmet/data/core/weather/surface-based-observations/synop',
#     'topics': ['origin/a/wis2/br-inmet/data/core/weather/surface-based-observations/synop'],
#     'status': 'operational',
#     'id': '0-76-0-1504208000000449'}},
#   {'id': '0-76-0-1506708000000369',
#    'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-50.350278, -9.340556, 154.0]},
#    'properties': {'name': 'SANTANA DO ARAGUAIA',
#     'wigos_station_identifier': '0-76-0-1506708000000369',
#     'traditional_station_identifier': '81982',
#     'barometer_height': 155.5,
#     'facility_type': 'landFixed',
#     'territory_name': 'BRA',
#     'wmo_region': 'southAmerica',
#     'url': 'https://oscar.wmo.int/surface/#/search/station/stationReportDetails/0-76-0-1506708000000369',
#     'topic': 'origin/a/wis2/br-inmet/data/core/weather/surface-based-observations/synop',
#     'topics': ['origin/a/wis2/br-inmet/data/core/weather/surface-based-observations/synop'],
#     'status': 'operational',
#     'id': '0-76-0-1506708000000369'}},
#   {'id': '0-76-0-1506203000000383',
#    'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-47.356667, -0.618889, 23.18]},
#    'properties': {'name': 'SALINOPOLIS',
#     'wigos_station_identifier': '0-76-0-1506203000000383',
#     'traditional_station_identifier': '81660',
#     'barometer_height': 24.68,
#     'facility_type': 'landFixed',
#     'territory_name': 'BRA',
#     'wmo_region': 'southAmerica',
#     'url': 'https://oscar.wmo.int/surface/#/search/station/stationReportDetails/0-76-0-1506203000000383',
#     'topic': 'origin/a/wis2/br-inmet/data/core/weather/surface-based-observations/synop',
#     'topics': ['origin/a/wis2/br-inmet/data/core/weather/surface-based-observations/synop'],
#     'status': 'operational',
#     'id': '0-76-0-1506203000000383'}},
#   {'id': '0-76-0-1508100000000300',
#    'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-49.675, -3.822778, 137.94]},
#    'properties': {'name': 'TUCURUI',
#     'wigos_station_identifier': '0-76-0-1508100000000300',
#     'traditional_station_identifier': '81743',
#     'barometer_height': 139.44,
#     'facility_type': 'landFixed',
#     'territory_name': 'BRA',
#     'wmo_region': 'southAmerica',
#     'url': 'https://oscar.wmo.int/surface/#/search/station/stationReportDetails/0-76-0-1508100000000300',
#     'topic': 'origin/a/wis2/br-inmet/data/core/weather/surface-based-observations/synop',
#     'topics': ['origin/a/wis2/br-inmet/data/core/weather/surface-based-observations/synop'],
#     'status': 'operational',
#     'id': '0-76-0-1508100000000300'}},
#   {'id': '0-76-0-1200435000000413',
#    'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-69.926389, -9.358333, 184.51]},
#    'properties': {'name': 'PARQUE ESTADUAL CHANDLESS',
#     'wigos_station_identifier': '0-76-0-1200435000000413',
#     'traditional_station_identifier': '81963',
#     'barometer_height': 186.01,
#     'facility_type': 'landFixed',
#     'territory_name': 'BRA',
#     'wmo_region': 'southAmerica',
#     'url': 'https://oscar.wmo.int/surface/#/search/station/stationReportDetails/0-76-0-1200435000000413',
#     'topic': 'origin/a/wis2/br-inmet/data/core/weather/surface-based-observations/synop',
#     'topics': ['origin/a/wis2/br-inmet/data/core/weather/surface-based-observations/synop'],
#     'status': 'operational',
#     'id': '0-76-0-1200435000000413'}},
#   {'id': '0-76-0-1200203000000498',
#    'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-72.681389, -7.610833, 220.0]},
#    'properties': {'name': 'CRUZEIRO DO SUL',
#     'wigos_station_identifier': '0-76-0-1200203000000498',
#     'traditional_station_identifier': '81881',
#     'barometer_height': 221.5,
#     'facility_type': 'landFixed',
#     'territory_name': 'BRA',
#     'wmo_region': 'southAmerica',
#     'url': 'https://oscar.wmo.int/surface/#/search/station/stationReportDetails/0-76-0-1200203000000498',
#     'topic': 'origin/a/wis2/br-inmet/data/core/weather/surface-based-observations/synop',
#     'topics': ['origin/a/wis2/br-inmet/data/core/weather/surface-based-observations/synop'],
#     'status': 'operational',
#     'id': '0-76-0-1200203000000498'}},
#   {'id': '0-76-0-1301407000000483',
#    'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-69.868611, -6.650278, 121.54]},
#    'properties': {'name': 'EIRUNEPE',
#     'wigos_station_identifier': '0-76-0-1301407000000483',
#     'traditional_station_identifier': '81843',
#     'barometer_height': 123.04,
#     'facility_type': 'landFixed',
#     'territory_name': 'BRA',
#     'wmo_region': 'southAmerica',
#     'url': 'https://oscar.wmo.int/surface/#/search/station/stationReportDetails/0-76-0-1301407000000483',
#     'topic': 'origin/a/wis2/br-inmet/data/core/weather/surface-based-observations/synop',
#     'topics': ['origin/a/wis2/br-inmet/data/core/weather/surface-based-observations/synop'],
#     'status': 'operational',
#     'id': '0-76-0-1301407000000483'}},
#   {'id': '0-76-0-1300300000000339',
#    'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-59.129444, -3.583333, 19.9]},
#    'properties': {'name': 'AUTAZES',
#     'wigos_station_identifier': '0-76-0-1300300000000339',
#     'traditional_station_identifier': '81732',
#     'barometer_height': 21.4,
#     'facility_type': 'landFixed',
#     'territory_name': 'BRA',
#     'wmo_region': 'southAmerica',
#     'url': 'https://oscar.wmo.int/surface/#/search/station/stationReportDetails/0-76-0-1300300000000339',
#     'topic': 'origin/a/wis2/br-inmet/data/core/weather/surface-based-observations/synop',
#     'topics': ['origin/a/wis2/br-inmet/data/core/weather/surface-based-observations/synop'],
#     'status': 'operational',
#     'id': '0-76-0-1300300000000339'}},
#   {'id': '0-76-0-1300144000000406',
#    'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-59.888611, -7.205556, 156.97]},
#    'properties': {'name': 'APUI',
#     'wigos_station_identifier': '0-76-0-1300144000000406',
#     'traditional_station_identifier': '81893',
#     'barometer_height': 158.47,
#     'facility_type': 'landFixed',
#     'territory_name': 'BRA',
#     'wmo_region': 'southAmerica',
#     'url': 'https://oscar.wmo.int/surface/#/search/station/stationReportDetails/0-76-0-1300144000000406',
#     'topic': 'origin/a/wis2/br-inmet/data/core/weather/surface-based-observations/synop',
#     'topics': ['origin/a/wis2/br-inmet/data/core/weather/surface-based-observations/synop'],
#     'status': 'operational',
#     'id': '0-76-0-1300144000000406'}},
#   {'id': '0-76-0-1381098000000370',
#    'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-53.884444, -14.925, 662.0]},
#    'properties': {'name': 'SANTO ANTONIO DO LESTE',
#     'wigos_station_identifier': '0-76-0-1381098000000370',
#     'traditional_station_identifier': '86685',
#     'barometer_height': 663.5,
#     'facility_type': 'landFixed',
#     'territory_name': 'BRA',
#     'wmo_region': 'southAmerica',
#     'url': 'https://oscar.wmo.int/surface/#/search/station/stationReportDetails/0-76-0-1381098000000370',
#     'topic': 'origin/a/wis2/br-inmet/data/core/weather/surface-based-observations/synop',
#     'topics': ['origin/a/wis2/br-inmet/data/core/weather/surface-based-observations/synop'],
#     'status': 'operational',
#     'id': '0-76-0-1381098000000370'}},
#   {'id': '0-76-0-1500602000000468',
#    'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-55.787778, -6.32, 259.88]},
#    'properties': {'name': 'MINA DO PALITO',
#     'wigos_station_identifier': '0-76-0-1500602000000468',
#     'traditional_station_identifier': '81855',
#     'barometer_height': 261.38,
#     'facility_type': 'landFixed',
#     'territory_name': 'BRA',
#     'wmo_region': 'southAmerica',
#     'url': 'https://oscar.wmo.int/surface/#/search/station/stationReportDetails/0-76-0-1500602000000468',
#     'topic': 'origin/a/wis2/br-inmet/data/core/weather/surface-based-observations/synop',
#     'topics': ['origin/a/wis2/br-inmet/data/core/weather/surface-based-observations/synop'],
#     'status': 'operational',
#     'id': '0-76-0-1500602000000468'}},
#   {'id': '0-76-0-1501808000000561',
#    'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-50.478056, -1.680278, 11.0]},
#    'properties': {'name': 'BREVES',
#     'wigos_station_identifier': '0-76-0-1501808000000561',
#     'traditional_station_identifier': '81673',
#     'barometer_height': 12.5,
#     'facility_type': 'landFixed',
#     'territory_name': 'BRA',
#     'wmo_region': 'southAmerica',
#     'url': 'https://oscar.wmo.int/surface/#/search/station/stationReportDetails/0-76-0-1501808000000561',
#     'topic': 'origin/a/wis2/br-inmet/data/core/weather/surface-based-observations/synop',
#     'topics': ['origin/a/wis2/br-inmet/data/core/weather/surface-based-observations/synop'],
#     'status': 'operational',
#     'id': '0-76-0-1501808000000561'}},
#   {'id': '0-76-0-1505536000000418',
#    'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-50.142222, -6.0775, 707.0]},
#    'properties': {'name': 'SERRA DOS CARAJAS',
#     'wigos_station_identifier': '0-76-0-1505536000000418',
#     'traditional_station_identifier': '81860',
#     'barometer_height': 708.5,
#     'facility_type': 'landFixed',
#     'territory_name': 'BRA',
#     'wmo_region': 'southAmerica',
#     'url': 'https://oscar.wmo.int/surface/#/search/station/stationReportDetails/0-76-0-1505536000000418',
#     'topic': 'origin/a/wis2/br-inmet/data/core/weather/surface-based-observations/synop',
#     'topics': ['origin/a/wis2/br-inmet/data/core/weather/surface-based-observations/synop'],
#     'status': 'operational',
#     'id': '0-76-0-1505536000000418'}},
#   {'id': '0-76-0-1505502000000258',
#    'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-47.495, -2.900556, 88.0]},
#    'properties': {'name': 'PARAGOMINAS',
#     'wigos_station_identifier': '0-76-0-1505502000000258',
#     'traditional_station_identifier': '81745',
#     'barometer_height': 89.5,
#     'facility_type': 'landFixed',
#     'territory_name': 'BRA',
#     'wmo_region': 'southAmerica',
#     'url': 'https://oscar.wmo.int/surface/#/search/station/stationReportDetails/0-76-0-1505502000000258',
#     'topic': 'origin/a/wis2/br-inmet/data/core/weather/surface-based-observations/synop',
#     'topics': ['origin/a/wis2/br-inmet/data/core/weather/surface-based-observations/synop'],
#     'status': 'operational',
#     'id': '0-76-0-1505502000000258'}},
#   {'id': '0-76-0-1600253000000554',
#    'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-50.823611, 0.567778, 21.0]},
#    'properties': {'name': 'ITAUBAL',
#     'wigos_station_identifier': '0-76-0-1600253000000554',
#     'traditional_station_identifier': '81636',
#     'barometer_height': 22.5,
#     'facility_type': 'landFixed',
#     'territory_name': 'BRA',
#     'wmo_region': 'southAmerica',
#     'url': 'https://oscar.wmo.int/surface/#/search/station/stationReportDetails/0-76-0-1600253000000554',
#     'topic': 'origin/a/wis2/br-inmet/data/core/weather/surface-based-observations/synop',
#     'topics': ['origin/a/wis2/br-inmet/data/core/weather/surface-based-observations/synop'],
#     'status': 'operational',
#     'id': '0-76-0-1600253000000554'}},
#   {'id': '0-76-0-2305100000000194',
#    'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-38.958889, -4.229167, 865.53]},
#    'properties': {'name': 'GUARAMIRANGA',
#     'wigos_station_identifier': '0-76-0-2305100000000194',
#     'traditional_station_identifier': '81797',
#     'barometer_height': 867.03,
#     'facility_type': 'landFixed',
#     'territory_name': 'BRA',
#     'wmo_region': 'southAmerica',
#     'url': 'https://oscar.wmo.int/surface/#/search/station/stationReportDetails/0-76-0-2305100000000194',
#     'topic': 'origin/a/wis2/br-inmet/data/core/weather/surface-based-observations/synop',
#     'topics': ['origin/a/wis2/br-inmet/data/core/weather/surface-based-observations/synop'],
#     'status': 'operational',
#     'id': '0-76-0-2305100000000194'}},
#   {'id': '0-76-0-2302701000000307',
#    'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-40.362778, -7.077778, 577.95]},
#    'properties': {'name': 'CAMPOS SALES',
#     'wigos_station_identifier': '0-76-0-2302701000000307',
#     'traditional_station_identifier': '81909',
#     'barometer_height': 579.45,
#     'facility_type': 'landFixed',
#     'territory_name': 'BRA',
#     'wmo_region': 'southAmerica',
#     'url': 'https://oscar.wmo.int/surface/#/search/station/stationReportDetails/0-76-0-2302701000000307',
#     'topic': 'origin/a/wis2/br-inmet/data/core/weather/surface-based-observations/synop',
#     'topics': ['origin/a/wis2/br-inmet/data/core/weather/surface-based-observations/synop'],
#     'status': 'operational',
#     'id': '0-76-0-2302701000000307'}},
#   {'id': '0-76-0-2304400000000057',
#    'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-38.537778, -3.815833, 29.55]},
#    'properties': {'name': 'FORTALEZA',
#     'wigos_station_identifier': '0-76-0-2304400000000057',
#     'traditional_station_identifier': '81758',
#     'barometer_height': 31.05,
#     'facility_type': 'landFixed',
#     'territory_name': 'BRA',
#     'wmo_region': 'southAmerica',
#     'url': 'https://oscar.wmo.int/surface/#/search/station/stationReportDetails/0-76-0-2304400000000057',
#     'topic': 'origin/a/wis2/br-inmet/data/core/weather/surface-based-observations/synop',
#     'topics': ['origin/a/wis2/br-inmet/data/core/weather/surface-based-observations/synop'],
#     'status': 'operational',
#     'id': '0-76-0-2304400000000057'}},
#   {'id': '0-76-0-2306405000000421',
#    'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-39.588611, -3.484167, 104.49]},
#    'properties': {'name': 'ITAPIPOCA',
#     'wigos_station_identifier': '0-76-0-2306405000000421',
#     'traditional_station_identifier': '81756',
#     'barometer_height': 105.99,
#     'facility_type': 'landFixed',
#     'territory_name': 'BRA',
#     'wmo_region': 'southAmerica',
#     'url': 'https://oscar.wmo.int/surface/#/search/station/stationReportDetails/0-76-0-2306405000000421',
#     'topic': 'origin/a/wis2/br-inmet/data/core/weather/surface-based-observations/synop',
#     'topics': ['origin/a/wis2/br-inmet/data/core/weather/surface-based-observations/synop'],
#     'status': 'operational',
#     'id': '0-76-0-2306405000000421'}},
#   {'id': '0-76-0-2306900000000426',
#    'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-38.627778, -5.905556, 149.31]},
#    'properties': {'name': 'JAGUARIBE',
#     'wigos_station_identifier': '0-76-0-2306900000000426',
#     'traditional_station_identifier': '81833',
#     'barometer_height': 150.81,
#     'facility_type': 'landFixed',
#     'territory_name': 'BRA',
#     'wmo_region': 'southAmerica',
#     'url': 'https://oscar.wmo.int/surface/#/search/station/stationReportDetails/0-76-0-2306900000000426',
#     'topic': 'origin/a/wis2/br-inmet/data/core/weather/surface-based-observations/synop',
#     'topics': ['origin/a/wis2/br-inmet/data/core/weather/surface-based-observations/synop'],
#     'status': 'operational',
#     'id': '0-76-0-2306900000000426'}},
#   {'id': '0-76-0-2707404000000424',
#    'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-35.565833, -9.2875, 13.69]},
#    'properties': {'name': 'SAO LUIS DO QUITUNDE',
#     'wigos_station_identifier': '0-76-0-2707404000000424',
#     'traditional_station_identifier': '81997',
#     'barometer_height': 15.19,
#     'facility_type': 'landFixed',
#     'territory_name': 'BRA',
#     'wmo_region': 'southAmerica',
#     'url': 'https://oscar.wmo.int/surface/#/search/station/stationReportDetails/0-76-0-2707404000000424',
#     'topic': 'origin/a/wis2/br-inmet/data/core/weather/surface-based-observations/synop',
#     'topics': ['origin/a/wis2/br-inmet/data/core/weather/surface-based-observations/synop'],
#     'status': 'operational',
#     'id': '0-76-0-2707404000000424'}},
#   {'id': '0-76-0-2700300000000353',
#    'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-36.619167, -9.804444, 236.84]},
#    'properties': {'name': 'ARAPIRACA',
#     'wigos_station_identifier': '0-76-0-2700300000000353',
#     'traditional_station_identifier': '81996',
#     'barometer_height': 238.34,
#     'facility_type': 'landFixed',
#     'territory_name': 'BRA',
#     'wmo_region': 'southAmerica',
#     'url': 'https://oscar.wmo.int/surface/#/search/station/stationReportDetails/0-76-0-2700300000000353',
#     'topic': 'origin/a/wis2/br-inmet/data/core/weather/surface-based-observations/synop',
#     'topics': ['origin/a/wis2/br-inmet/data/core/weather/surface-based-observations/synop'],
#     'status': 'operational',
#     'id': '0-76-0-2700300000000353'}},
#   {'id': '0-76-0-2802908000000544',
#    'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-37.471389, -10.671667, 213.0]},
#    'properties': {'name': 'ITABAIANA',
#     'wigos_station_identifier': '0-76-0-2802908000000544',
#     'traditional_station_identifier': '86601',
#     'barometer_height': 214.5,
#     'facility_type': 'landFixed',
#     'territory_name': 'BRA',
#     'wmo_region': 'southAmerica',
#     'url': 'https://oscar.wmo.int/surface/#/search/station/stationReportDetails/0-76-0-2802908000000544',
#     'topic': 'origin/a/wis2/br-inmet/data/core/weather/surface-based-observations/synop',
#     'topics': ['origin/a/wis2/br-inmet/data/core/weather/surface-based-observations/synop'],
#     'status': 'operational',
#     'id': '0-76-0-2802908000000544'}},
#   {'id': '0-76-0-2900702000000328',
#    'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-41.388889, -12.557778, 438.09]},
#    'properties': {'name': 'LENCOIS',
#     'wigos_station_identifier': '0-76-0-2900702000000328',
#     'traditional_station_identifier': '86654',
#     'barometer_height': 439.59,
#     'facility_type': 'landFixed',
#     'territory_name': 'BRA',
#     'wmo_region': 'southAmerica',
#     'url': 'https://oscar.wmo.int/surface/#/search/station/stationReportDetails/0-76-0-2900702000000328',
#     'topic': 'origin/a/wis2/br-inmet/data/core/weather/surface-based-observations/synop',
#     'topics': ['origin/a/wis2/br-inmet/data/core/weather/surface-based-observations/synop'],
#     'status': 'operational',
#     'id': '0-76-0-2900702000000328'}},
#   {'id': '0-76-0-2805505000000327',
#    'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-38.108333, -10.738056, 367.01]},
#    'properties': {'name': 'POCO VERDE',
#     'wigos_station_identifier': '0-76-0-2805505000000327',
#     'traditional_station_identifier': '86614',
#     'barometer_height': 368.51,
#     'facility_type': 'landFixed',
#     'territory_name': 'BRA',
#     'wmo_region': 'southAmerica',
#     'url': 'https://oscar.wmo.int/surface/#/search/station/stationReportDetails/0-76-0-2805505000000327',
#     'topic': 'origin/a/wis2/br-inmet/data/core/weather/surface-based-observations/synop',
#     'topics': ['origin/a/wis2/br-inmet/data/core/weather/surface-based-observations/synop'],
#     'status': 'operational',
#     'id': '0-76-0-2805505000000327'}},
#   {'id': '0-76-0-2910800000000195',
#    'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-38.9675, -12.196111, 229.64]},
#    'properties': {'name': 'FEIRA DE SANTANA',
#     'wigos_station_identifier': '0-76-0-2910800000000195',
#     'traditional_station_identifier': '86658',
#     'barometer_height': 231.14,
#     'facility_type': 'landFixed',
#     'territory_name': 'BRA',
#     'wmo_region': 'southAmerica',
#     'url': 'https://oscar.wmo.int/surface/#/search/station/stationReportDetails/0-76-0-2910800000000195',
#     'topic': 'origin/a/wis2/br-inmet/data/core/weather/surface-based-observations/synop',
#     'topics': ['origin/a/wis2/br-inmet/data/core/weather/surface-based-observations/synop'],
#     'status': 'operational',
#     'id': '0-76-0-2910800000000195'}},
#   {'id': '0-76-0-2928406000000198',
#    'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-44.536389, -11.003333, 450.0]},
#    'properties': {'name': 'SANTA RITA DE CASSIA',
#     'wigos_station_identifier': '0-76-0-2928406000000198',
#     'traditional_station_identifier': '86633',
#     'barometer_height': 451.5,
#     'facility_type': 'landFixed',
#     'territory_name': 'BRA',
#     'wmo_region': 'southAmerica',
#     'url': 'https://oscar.wmo.int/surface/#/search/station/stationReportDetails/0-76-0-2928406000000198',
#     'topic': 'origin/a/wis2/br-inmet/data/core/weather/surface-based-observations/synop',
#     'topics': ['origin/a/wis2/br-inmet/data/core/weather/surface-based-observations/synop'],
#     'status': 'operational',
#     'id': '0-76-0-2928406000000198'}},
#   {'id': '0-76-0-2925303000000396',
#    'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-39.1825, -16.388889, 86.36]},
#    'properties': {'name': 'PORTO SEGURO',
#     'wigos_station_identifier': '0-76-0-2925303000000396',
#     'traditional_station_identifier': '86745',
#     'barometer_height': 87.86,
#     'facility_type': 'landFixed',
#     'territory_name': 'BRA',
#     'wmo_region': 'southAmerica',
#     'url': 'https://oscar.wmo.int/surface/#/search/station/stationReportDetails/0-76-0-2925303000000396',
#     'topic': 'origin/a/wis2/br-inmet/data/core/weather/surface-based-observations/synop',
#     'topics': ['origin/a/wis2/br-inmet/data/core/weather/surface-based-observations/synop'],
#     'status': 'operational',
#     'id': '0-76-0-2925303000000396'}},
#   {'id': '0-76-0-2925808000000366',
#    'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-39.616944, -10.984722, 310.11]},
#    'properties': {'name': 'QUEIMADAS',
#     'wigos_station_identifier': '0-76-0-2925808000000366',
#     'traditional_station_identifier': '86612',
#     'barometer_height': 311.61,
#     'facility_type': 'landFixed',
#     'territory_name': 'BRA',
#     'wmo_region': 'southAmerica',
#     'url': 'https://oscar.wmo.int/surface/#/search/station/stationReportDetails/0-76-0-2925808000000366',
#     'topic': 'origin/a/wis2/br-inmet/data/core/weather/surface-based-observations/synop',
#     'topics': ['origin/a/wis2/br-inmet/data/core/weather/surface-based-observations/synop'],
#     'status': 'operational',
#     'id': '0-76-0-2925808000000366'}},
#   {'id': '0-76-0-2930501000000361',
#    'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-39.023056, -11.664722, 337.79]},
#    'properties': {'name': 'SERRINHA',
#     'wigos_station_identifier': '0-76-0-2930501000000361',
#     'traditional_station_identifier': '86637',
#     'barometer_height': 339.29,
#     'facility_type': 'landFixed',
#     'territory_name': 'BRA',
#     'wmo_region': 'southAmerica',
#     'url': 'https://oscar.wmo.int/surface/#/search/station/stationReportDetails/0-76-0-2930501000000361',
#     'topic': 'origin/a/wis2/br-inmet/data/core/weather/surface-based-observations/synop',
#     'topics': ['origin/a/wis2/br-inmet/data/core/weather/surface-based-observations/synop'],
#     'status': 'operational',
#     'id': '0-76-0-2930501000000361'}},
#   {'id': '0-76-0-2926004000000321',
#    'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-42.077222, -9.625556, 397.4]},
#    'properties': {'name': 'REMANSO',
#     'wigos_station_identifier': '0-76-0-2926004000000321',
#     'traditional_station_identifier': '81990',
#     'barometer_height': 398.9,
#     'facility_type': 'landFixed',
#     'territory_name': 'BRA',
#     'wmo_region': 'southAmerica',
#     'url': 'https://oscar.wmo.int/surface/#/search/station/stationReportDetails/0-76-0-2926004000000321',
#     'topic': 'origin/a/wis2/br-inmet/data/core/weather/surface-based-observations/synop',
#     'topics': ['origin/a/wis2/br-inmet/data/core/weather/surface-based-observations/synop'],
#     'status': 'operational',
#     'id': '0-76-0-2926004000000321'}},
#   {'id': '0-76-0-3116159000000215',
#    'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-45.6175, -15.300278, 873.2]},
#    'properties': {'name': 'CHAPADA GAUCHA',
#     'wigos_station_identifier': '0-76-0-3116159000000215',
#     'traditional_station_identifier': '86719',
#     'barometer_height': 874.7,
#     'facility_type': 'landFixed',
#     'territory_name': 'BRA',
#     'wmo_region': 'southAmerica',
#     'url': 'https://oscar.wmo.int/surface/#/search/station/stationReportDetails/0-76-0-3116159000000215',
#     'topic': 'origin/a/wis2/br-inmet/data/core/weather/surface-based-observations/synop',
#     'topics': ['origin/a/wis2/br-inmet/data/core/weather/surface-based-observations/synop'],
#     'status': 'operational',
#     'id': '0-76-0-3116159000000215'}},
#   {'id': '0-76-0-3127701000000197',
#    'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-41.977007, -18.830354, 198.24]},
#    'properties': {'name': 'GOVERNADOR VALADARES',
#     'wigos_station_identifier': '0-76-0-3127701000000197',
#     'traditional_station_identifier': '86783',
#     'barometer_height': 199.74,
#     'facility_type': 'landFixed',
#     'territory_name': 'BRA',
#     'wmo_region': 'southAmerica',
#     'url': 'https://oscar.wmo.int/surface/#/search/station/stationReportDetails/0-76-0-3127701000000197',
#     'topic': 'origin/a/wis2/br-inmet/data/core/weather/surface-based-observations/synop',
#     'topics': ['origin/a/wis2/br-inmet/data/core/weather/surface-based-observations/synop'],
#     'status': 'operational',
#     'id': '0-76-0-3127701000000197'}},
#   {'id': '0-76-0-3301207000000583',
#    'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-42.600833, -21.938611, 293.0]},
#    'properties': {'name': 'CARMO',
#     'wigos_station_identifier': '0-76-0-3301207000000583',
#     'traditional_station_identifier': '84824',
#     'barometer_height': 294.5,
#     'facility_type': 'landFixed',
#     'territory_name': 'BRA',
#     'wmo_region': 'southAmerica',
#     'url': 'https://oscar.wmo.int/surface/#/search/station/stationReportDetails/0-76-0-3301207000000583',
#     'topic': 'origin/a/wis2/br-inmet/data/core/weather/surface-based-observations/synop',
#     'topics': ['origin/a/wis2/br-inmet/data/core/weather/surface-based-observations/synop'],
#     'status': 'operational',
#     'id': '0-76-0-3301207000000583'}},
#   {'id': '0-76-0-3505500000000460',
#    'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-48.545, -20.559167, 534.36]},
#    'properties': {'name': 'BARRETOS',
#     'wigos_station_identifier': '0-76-0-3505500000000460',
#     'traditional_station_identifier': '86816',
#     'barometer_height': 535.86,
#     'facility_type': 'landFixed',
#     'territory_name': 'BRA',
#     'wmo_region': 'southAmerica',
#     'url': 'https://oscar.wmo.int/surface/#/search/station/stationReportDetails/0-76-0-3505500000000460',
#     'topic': 'origin/a/wis2/br-inmet/data/core/weather/surface-based-observations/synop',
#     'topics': ['origin/a/wis2/br-inmet/data/core/weather/surface-based-observations/synop'],
#     'status': 'operational',
#     'id': '0-76-0-3505500000000460'}},
#   {'id': '0-76-0-3306107000000111',
#    'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-43.695556, -22.358056, 370.0]},
#    'properties': {'name': 'VALENCA',
#     'wigos_station_identifier': '0-76-0-3306107000000111',
#     'traditional_station_identifier': '86875',
#     'barometer_height': 371.5,
#     'facility_type': 'landFixed',
#     'territory_name': 'BRA',
#     'wmo_region': 'southAmerica',
#     'url': 'https://oscar.wmo.int/surface/#/search/station/stationReportDetails/0-76-0-3306107000000111',
#     'topic': 'origin/a/wis2/br-inmet/data/core/weather/surface-based-observations/synop',
#     'topics': ['origin/a/wis2/br-inmet/data/core/weather/surface-based-observations/synop'],
#     'status': 'operational',
#     'id': '0-76-0-3306107000000111'}},
#   {'id': '0-76-0-3504503000000107',
#    'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-48.941111, -23.101667, 776.36]},
#    'properties': {'name': 'AVARE',
#     'wigos_station_identifier': '0-76-0-3504503000000107',
#     'traditional_station_identifier': '86904',
#     'barometer_height': 777.86,
#     'facility_type': 'landFixed',
#     'territory_name': 'BRA',
#     'wmo_region': 'southAmerica',
#     'url': 'https://oscar.wmo.int/surface/#/search/station/stationReportDetails/0-76-0-3504503000000107',
#     'topic': 'origin/a/wis2/br-inmet/data/core/weather/surface-based-observations/synop',
#     'topics': ['origin/a/wis2/br-inmet/data/core/weather/surface-based-observations/synop'],
#     'status': 'operational',
#     'id': '0-76-0-3504503000000107'}},
#   {'id': '0-76-0-3525706000000249',
#    'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-49.920278, -21.085556, 408.35]},
#    'properties': {'name': 'JOSE BONIFACIO',
#     'wigos_station_identifier': '0-76-0-3525706000000249',
#     'traditional_station_identifier': '86839',
#     'barometer_height': 409.85,
#     'facility_type': 'landFixed',
#     'territory_name': 'BRA',
#     'wmo_region': 'southAmerica',
#     'url': 'https://oscar.wmo.int/surface/#/search/station/stationReportDetails/0-76-0-3525706000000249',
#     'topic': 'origin/a/wis2/br-inmet/data/core/weather/surface-based-observations/synop',
#     'topics': ['origin/a/wis2/br-inmet/data/core/weather/surface-based-observations/synop'],
#     'status': 'operational',
#     'id': '0-76-0-3525706000000249'}},
#   {'id': '0-76-0-3519600000000267',
#    'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-48.799722, -21.855556, 496.75]},
#    'properties': {'name': 'IBITINGA',
#     'wigos_station_identifier': '0-76-0-3519600000000267',
#     'traditional_station_identifier': '86843',
#     'barometer_height': 498.25,
#     'facility_type': 'landFixed',
#     'territory_name': 'BRA',
#     'wmo_region': 'southAmerica',
#     'url': 'https://oscar.wmo.int/surface/#/search/station/stationReportDetails/0-76-0-3519600000000267',
#     'topic': 'origin/a/wis2/br-inmet/data/core/weather/surface-based-observations/synop',
#     'topics': ['origin/a/wis2/br-inmet/data/core/weather/surface-based-observations/synop'],
#     'status': 'operational',
#     'id': '0-76-0-3519600000000267'}},
#   {'id': '0-76-0-3538709000000110',
#    'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-47.623333, -22.703056, 566.46]},
#    'properties': {'name': 'PIRACICABA',
#     'wigos_station_identifier': '0-76-0-3538709000000110',
#     'traditional_station_identifier': '86868',
#     'barometer_height': 567.96,
#     'facility_type': 'landFixed',
#     'territory_name': 'BRA',
#     'wmo_region': 'southAmerica',
#     'url': 'https://oscar.wmo.int/surface/#/search/station/stationReportDetails/0-76-0-3538709000000110',
#     'topic': 'origin/a/wis2/br-inmet/data/core/weather/surface-based-observations/synop',
#     'topics': ['origin/a/wis2/br-inmet/data/core/weather/surface-based-observations/synop'],
#     'status': 'operational',
#     'id': '0-76-0-3538709000000110'}},
#   {'id': '0-76-0-3542602000000538',
#    'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-47.864167, -24.533056, 35.0]},
#    'properties': {'name': 'REGISTRO',
#     'wigos_station_identifier': '0-76-0-3542602000000538',
#     'traditional_station_identifier': '86915',
#     'barometer_height': 36.5,
#     'facility_type': 'landFixed',
#     'territory_name': 'BRA',
#     'wmo_region': 'southAmerica',
#     'url': 'https://oscar.wmo.int/surface/#/search/station/stationReportDetails/0-76-0-3542602000000538',
#     'topic': 'origin/a/wis2/br-inmet/data/core/weather/surface-based-observations/synop',
#     'topics': ['origin/a/wis2/br-inmet/data/core/weather/surface-based-observations/synop'],
#     'status': 'operational',
#     'id': '0-76-0-3542602000000538'}},
#   {'id': '0-76-0-3527108000000105',
#    'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-49.734722, -21.666111, 460.65]},
#    'properties': {'name': 'LINS',
#     'wigos_station_identifier': '0-76-0-3527108000000105',
#     'traditional_station_identifier': '86840',
#     'barometer_height': 462.15,
#     'facility_type': 'landFixed',
#     'territory_name': 'BRA',
#     'wmo_region': 'southAmerica',
#     'url': 'https://oscar.wmo.int/surface/#/search/station/stationReportDetails/0-76-0-3527108000000105',
#     'topic': 'origin/a/wis2/br-inmet/data/core/weather/surface-based-observations/synop',
#     'topics': ['origin/a/wis2/br-inmet/data/core/weather/surface-based-observations/synop'],
#     'status': 'operational',
#     'id': '0-76-0-3527108000000105'}},
#   {'id': '0-76-0-4109906000000139',
#    'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-53.635833, -23.390278, 381.29]},
#    'properties': {'name': 'ICARAIMA',
#     'wigos_station_identifier': '0-76-0-4109906000000139',
#     'traditional_station_identifier': '86897',
#     'barometer_height': 382.79,
#     'facility_type': 'landFixed',
#     'territory_name': 'BRA',
#     'wmo_region': 'southAmerica',
#     'url': 'https://oscar.wmo.int/surface/#/search/station/stationReportDetails/0-76-0-4109906000000139',
#     'topic': 'origin/a/wis2/br-inmet/data/core/weather/surface-based-observations/synop',
#     'topics': ['origin/a/wis2/br-inmet/data/core/weather/surface-based-observations/synop'],
#     'status': 'operational',
#     'id': '0-76-0-4109906000000139'}},
#   {'id': '0-76-0-4108601000000119',
#    'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-53.048889, -24.183889, 481.0]},
#    'properties': {'name': 'GOIOERE',
#     'wigos_station_identifier': '0-76-0-4108601000000119',
#     'traditional_station_identifier': '86917',
#     'barometer_height': 482.5,
#     'facility_type': 'landFixed',
#     'territory_name': 'BRA',
#     'wmo_region': 'southAmerica',
#     'url': 'https://oscar.wmo.int/surface/#/search/station/stationReportDetails/0-76-0-4108601000000119',
#     'topic': 'origin/a/wis2/br-inmet/data/core/weather/surface-based-observations/synop',
#     'topics': ['origin/a/wis2/br-inmet/data/core/weather/surface-based-observations/synop'],
#     'status': 'operational',
#     'id': '0-76-0-4108601000000119'}},
#   {'id': '0-76-0-4115200000000142',
#    'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-51.932778, -23.405278, 548.51]},
#    'properties': {'name': 'MARINGA',
#     'wigos_station_identifier': '0-76-0-4115200000000142',
#     'traditional_station_identifier': '86899',
#     'barometer_height': 550.01,
#     'facility_type': 'landFixed',
#     'territory_name': 'BRA',
#     'wmo_region': 'southAmerica',
#     'url': 'https://oscar.wmo.int/surface/#/search/station/stationReportDetails/0-76-0-4115200000000142',
#     'topic': 'origin/a/wis2/br-inmet/data/core/weather/surface-based-observations/synop',
#     'topics': ['origin/a/wis2/br-inmet/data/core/weather/surface-based-observations/synop'],
#     'status': 'operational',
#     'id': '0-76-0-4115200000000142'}},
#   {'id': '0-76-0-4208450000000210',
#    'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-48.641667, -26.081389, 6.18]},
#    'properties': {'name': 'ITAPOA',
#     'wigos_station_identifier': '0-76-0-4208450000000210',
#     'traditional_station_identifier': '86947',
#     'barometer_height': 7.68,
#     'facility_type': 'landFixed',
#     'territory_name': 'BRA',
#     'wmo_region': 'southAmerica',
#     'url': 'https://oscar.wmo.int/surface/#/search/station/stationReportDetails/0-76-0-4208450000000210',
#     'topic': 'origin/a/wis2/br-inmet/data/core/weather/surface-based-observations/synop',
#     'topics': ['origin/a/wis2/br-inmet/data/core/weather/surface-based-observations/synop'],
#     'status': 'operational',
#     'id': '0-76-0-4208450000000210'}},
#   {'id': '0-76-0-4218905000000213',
#    'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-49.479722, -28.126944, 1790.38]},
#    'properties': {'name': 'BOM JARDIM DA SERRA - MORRO DA IGREJA',
#     'wigos_station_identifier': '0-76-0-4218905000000213',
#     'traditional_station_identifier': '86968',
#     'barometer_height': 1791.88,
#     'facility_type': 'landFixed',
#     'territory_name': 'BRA',
#     'wmo_region': 'southAmerica',
#     'url': 'https://oscar.wmo.int/surface/#/search/station/stationReportDetails/0-76-0-4218905000000213',
#     'topic': 'origin/a/wis2/br-inmet/data/core/weather/surface-based-observations/synop',
#     'topics': ['origin/a/wis2/br-inmet/data/core/weather/surface-based-observations/synop'],
#     'status': 'operational',
#     'id': '0-76-0-4218905000000213'}},
#   {'id': '0-76-0-4217204000000316',
#    'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-53.514167, -26.786389, 647.0]},
#    'properties': {'name': 'SAO MIGUEL DO OESTE',
#     'wigos_station_identifier': '0-76-0-4217204000000316',
#     'traditional_station_identifier': '86937',
#     'barometer_height': 648.5,
#     'facility_type': 'landFixed',
#     'territory_name': 'BRA',
#     'wmo_region': 'southAmerica',
#     'url': 'https://oscar.wmo.int/surface/#/search/station/stationReportDetails/0-76-0-4217204000000316',
#     'topic': 'origin/a/wis2/br-inmet/data/core/weather/surface-based-observations/synop',
#     'topics': ['origin/a/wis2/br-inmet/data/core/weather/surface-based-observations/synop'],
#     'status': 'operational',
#     'id': '0-76-0-4217204000000316'}},
#   {'id': '0-76-0-4312500000000315',
#    'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-50.906389, -31.248333, 3.82]},
#    'properties': {'name': 'MOSTARDAS',
#     'wigos_station_identifier': '0-76-0-4312500000000315',
#     'traditional_station_identifier': '86994',
#     'barometer_height': 5.32,
#     'facility_type': 'landFixed',
#     'territory_name': 'BRA',
#     'wmo_region': 'southAmerica',
#     'url': 'https://oscar.wmo.int/surface/#/search/station/stationReportDetails/0-76-0-4312500000000315',
#     'topic': 'origin/a/wis2/br-inmet/data/core/weather/surface-based-observations/synop',
#     'topics': ['origin/a/wis2/br-inmet/data/core/weather/surface-based-observations/synop'],
#     'status': 'operational',
#     'id': '0-76-0-4312500000000315'}},
#   {'id': '0-76-0-4310009000000491',
#    'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-53.111944, -28.653333, 455.27]},
#    'properties': {'name': 'IBIRUBA',
#     'wigos_station_identifier': '0-76-0-4310009000000491',
#     'traditional_station_identifier': '86974',
#     'barometer_height': 456.77,
#     'facility_type': 'landFixed',
#     'territory_name': 'BRA',
#     'wmo_region': 'southAmerica',
#     'url': 'https://oscar.wmo.int/surface/#/search/station/stationReportDetails/0-76-0-4310009000000491',
#     'topic': 'origin/a/wis2/br-inmet/data/core/weather/surface-based-observations/synop',
#     'topics': ['origin/a/wis2/br-inmet/data/core/weather/surface-based-observations/synop'],
#     'status': 'operational',
#     'id': '0-76-0-4310009000000491'}},
#   {'id': '0-76-0-4321501000000077',
#    'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-49.733333, -29.350278, 8.44]},
#    'properties': {'name': 'TORRES',
#     'wigos_station_identifier': '0-76-0-4321501000000077',
#     'traditional_station_identifier': '86981',
#     'barometer_height': 9.94,
#     'facility_type': 'landFixed',
#     'territory_name': 'BRA',
#     'wmo_region': 'southAmerica',
#     'url': 'https://oscar.wmo.int/surface/#/search/station/stationReportDetails/0-76-0-4321501000000077',
#     'topic': 'origin/a/wis2/br-inmet/data/core/weather/surface-based-observations/synop',
# ...
#   {'id': '0-2000-0-86639',
#    'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-37.683889, -12.035833, 31.9]},
#    'properties': {'name': 'CONDE',
#     'wigos_station_identifier': '0-2000-0-86639',
#     'traditional_station_identifier': '86639',
#     'barometer_height': 33.4,
#     'facility_type': 'landFixed',
#     'territory_name': 'BRA',
#     'wmo_region': 'southAmerica',
#     'url': 'https://oscar.wmo.int/surface/#/search/station/stationReportDetails/0-2000-0-86639',
#     'topic': 'origin/a/wis2/br-inmet/data/core/climate/surface-based-observations/daily',
#     'topics': ['origin/a/wis2/br-inmet/data/core/climate/surface-based-observations/daily'],
#     'status': 'operational',
#     'id': '0-2000-0-86639'}},
#   {'id': '0-2000-0-86634',
#    'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-43.138889, -11.084722, 407.5]},
#    'properties': {'name': 'BARRA',
#     'wigos_station_identifier': '0-2000-0-86634',
#     'traditional_station_identifier': '86634',
#     'barometer_height': 409.0,
#     'facility_type': 'landFixed',
#     'territory_name': 'BRA',
#     'wmo_region': 'southAmerica',
#     'url': 'https://oscar.wmo.int/surface/#/search/station/stationReportDetails/0-2000-0-86634',
#     'topic': 'origin/a/wis2/br-inmet/data/core/climate/surface-based-observations/daily',
#     'topics': ['origin/a/wis2/br-inmet/data/core/climate/surface-based-observations/daily'],
#     'status': 'operational',
#     'id': '0-2000-0-86634'}},
#   {'id': '0-2000-0-86635',
#    'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-41.864444, -11.328889, 768.42]},
#    'properties': {'name': 'IRECE',
#     'wigos_station_identifier': '0-2000-0-86635',
#     'traditional_station_identifier': '86635',
#     'barometer_height': 769.92,
#     'facility_type': 'landFixed',
#     'territory_name': 'BRA',
#     'wmo_region': 'southAmerica',
#     'url': 'https://oscar.wmo.int/surface/#/search/station/stationReportDetails/0-2000-0-86635',
#     'topic': 'origin/a/wis2/br-inmet/data/core/climate/surface-based-observations/daily',
#     'topics': ['origin/a/wis2/br-inmet/data/core/climate/surface-based-observations/daily'],
#     'status': 'operational',
#     'id': '0-2000-0-86635'}},
#   {'id': '0-2000-0-86613',
#    'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-38.996667, -10.537222, 431.96]},
#    'properties': {'name': 'EUCLIDES DA CUNHA',
#     'wigos_station_identifier': '0-2000-0-86613',
#     'traditional_station_identifier': '86613',
#     'barometer_height': 433.46,
#     'facility_type': 'landFixed',
#     'territory_name': 'BRA',
#     'wmo_region': 'southAmerica',
#     'url': 'https://oscar.wmo.int/surface/#/search/station/stationReportDetails/0-2000-0-86613',
#     'topic': 'origin/a/wis2/br-inmet/data/core/climate/surface-based-observations/daily',
#     'topics': ['origin/a/wis2/br-inmet/data/core/climate/surface-based-observations/daily'],
#     'status': 'operational',
#     'id': '0-2000-0-86613'}},
#   {'id': '0-2000-0-86653',
#    'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-43.213333, -12.193056, 425.12]},
#    'properties': {'name': 'IBOTIRAMA',
#     'wigos_station_identifier': '0-2000-0-86653',
#     'traditional_station_identifier': '86653',
#     'barometer_height': 426.62,
#     'facility_type': 'landFixed',
#     'territory_name': 'BRA',
#     'wmo_region': 'southAmerica',
#     'url': 'https://oscar.wmo.int/surface/#/search/station/stationReportDetails/0-2000-0-86653',
#     'topic': 'origin/a/wis2/br-inmet/data/core/climate/surface-based-observations/daily',
#     'topics': ['origin/a/wis2/br-inmet/data/core/climate/surface-based-observations/daily'],
#     'status': 'operational',
#     'id': '0-2000-0-86653'}},
#   {'id': '0-2000-0-86744',
#    'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-39.215278, -16.088056, 89.67]},
#    'properties': {'name': 'BELMONTE',
#     'wigos_station_identifier': '0-2000-0-86744',
#     'traditional_station_identifier': '86744',
#     'barometer_height': 91.17,
#     'facility_type': 'landFixed',
#     'territory_name': 'BRA',
#     'wmo_region': 'southAmerica',
#     'url': 'https://oscar.wmo.int/surface/#/search/station/stationReportDetails/0-2000-0-86744',
#     'topic': 'origin/a/wis2/br-inmet/data/core/climate/surface-based-observations/daily',
#     'topics': ['origin/a/wis2/br-inmet/data/core/climate/surface-based-observations/daily'],
#     'status': 'operational',
#     'id': '0-2000-0-86744'}},
#   {'id': '0-2000-0-86675',
#    'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-39.616944, -13.009444, 397.8]},
#    'properties': {'name': 'AMARGOSA',
#     'wigos_station_identifier': '0-2000-0-86675',
#     'traditional_station_identifier': '86675',
#     'barometer_height': 399.3,
#     'facility_type': 'landFixed',
#     'territory_name': 'BRA',
#     'wmo_region': 'southAmerica',
#     'url': 'https://oscar.wmo.int/surface/#/search/station/stationReportDetails/0-2000-0-86675',
#     'topic': 'origin/a/wis2/br-inmet/data/core/climate/surface-based-observations/daily',
#     'topics': ['origin/a/wis2/br-inmet/data/core/climate/surface-based-observations/daily'],
#     'status': 'operational',
#     'id': '0-2000-0-86675'}},
#   {'id': '0-2000-0-86610',
#    'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-41.206944, -10.455, 646.24]},
#    'properties': {'name': 'DELFINO',
#     'wigos_station_identifier': '0-2000-0-86610',
#     'traditional_station_identifier': '86610',
#     'barometer_height': 647.74,
#     'facility_type': 'landFixed',
#     'territory_name': 'BRA',
#     'wmo_region': 'southAmerica',
#     'url': 'https://oscar.wmo.int/surface/#/search/station/stationReportDetails/0-2000-0-86610',
#     'topic': 'origin/a/wis2/br-inmet/data/core/climate/surface-based-observations/daily',
#     'topics': ['origin/a/wis2/br-inmet/data/core/climate/surface-based-observations/daily'],
#     'status': 'operational',
#     'id': '0-2000-0-86610'}},
#   {'id': '0-2000-0-86696',
#    'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-41.672222, -14.181944, 473.37]},
#    'properties': {'name': 'BRUMADO',
#     'wigos_station_identifier': '0-2000-0-86696',
#     'traditional_station_identifier': '86696',
#     'barometer_height': 474.87,
#     'facility_type': 'landFixed',
#     'territory_name': 'BRA',
#     'wmo_region': 'southAmerica',
#     'url': 'https://oscar.wmo.int/surface/#/search/station/stationReportDetails/0-2000-0-86696',
#     'topic': 'origin/a/wis2/br-inmet/data/core/climate/surface-based-observations/daily',
#     'topics': ['origin/a/wis2/br-inmet/data/core/climate/surface-based-observations/daily'],
#     'status': 'operational',
#     'id': '0-2000-0-86696'}},
#   {'id': '0-2000-0-86698',
#    'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-39.6925, -14.171389, 132.11]},
#    'properties': {'name': 'IPIAU',
#     'wigos_station_identifier': '0-2000-0-86698',
#     'traditional_station_identifier': '86698',
#     'barometer_height': 133.61,
#     'facility_type': 'landFixed',
#     'territory_name': 'BRA',
#     'wmo_region': 'southAmerica',
#     'url': 'https://oscar.wmo.int/surface/#/search/station/stationReportDetails/0-2000-0-86698',
#     'topic': 'origin/a/wis2/br-inmet/data/core/climate/surface-based-observations/daily',
#     'topics': ['origin/a/wis2/br-inmet/data/core/climate/surface-based-observations/daily'],
#     'status': 'operational',
#     'id': '0-2000-0-86698'}},
#   {'id': '0-2000-0-81984',
#    'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-39.9125, -9.001389, 370.0]},
#    'properties': {'name': 'CURACA',
#     'wigos_station_identifier': '0-2000-0-81984',
#     'traditional_station_identifier': '81984',
#     'barometer_height': 371.5,
#     'facility_type': 'landFixed',
#     'territory_name': 'BRA',
#     'wmo_region': 'southAmerica',
#     'url': 'https://oscar.wmo.int/surface/#/search/station/stationReportDetails/0-2000-0-81984',
#     'topic': 'origin/a/wis2/br-inmet/data/core/climate/surface-based-observations/daily',
#     'topics': ['origin/a/wis2/br-inmet/data/core/climate/surface-based-observations/daily'],
#     'status': 'operational',
#     'id': '0-2000-0-81984'}},
#   {'id': '0-2000-0-86724',
#    'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-39.091389, -15.280278, 74.08]},
#    'properties': {'name': 'UNA',
#     'wigos_station_identifier': '0-2000-0-86724',
#     'traditional_station_identifier': '86724',
#     'barometer_height': 75.58,
#     'facility_type': 'landFixed',
#     'territory_name': 'BRA',
#     'wmo_region': 'southAmerica',
#     'url': 'https://oscar.wmo.int/surface/#/search/station/stationReportDetails/0-2000-0-86724',
#     'topic': 'origin/a/wis2/br-inmet/data/core/climate/surface-based-observations/daily',
#     'topics': ['origin/a/wis2/br-inmet/data/core/climate/surface-based-observations/daily'],
#     'status': 'operational',
#     'id': '0-2000-0-86724'}},
#   {'id': '0-2000-0-86660',
#    'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-38.495833, -12.808333, 31.0]},
#    'properties': {'name': 'SALVADOR (RADIO FAROL)',
#     'wigos_station_identifier': '0-2000-0-86660',
#     'traditional_station_identifier': '86660',
#     'barometer_height': 32.5,
#     'facility_type': 'landFixed',
#     'territory_name': 'BRA',
#     'wmo_region': 'southAmerica',
#     'url': 'https://oscar.wmo.int/surface/#/search/station/stationReportDetails/0-2000-0-86660',
#     'topic': 'origin/a/wis2/br-inmet/data/core/climate/surface-based-observations/daily',
#     'topics': ['origin/a/wis2/br-inmet/data/core/climate/surface-based-observations/daily'],
#     'status': 'operational',
#     'id': '0-2000-0-86660'}},
#   {'id': '0-2000-0-86600',
#    'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-37.431944, -10.207778, 271.0]},
#    'properties': {'name': 'NOSSA SENHORA DA GLORIA',
#     'wigos_station_identifier': '0-2000-0-86600',
#     'traditional_station_identifier': '86600',
#     'barometer_height': 272.5,
#     'facility_type': 'landFixed',
#     'territory_name': 'BRA',
#     'wmo_region': 'southAmerica',
#     'url': 'https://oscar.wmo.int/surface/#/search/station/stationReportDetails/0-2000-0-86600',
#     'topic': 'origin/a/wis2/br-inmet/data/core/climate/surface-based-observations/daily',
#     'topics': ['origin/a/wis2/br-inmet/data/core/climate/surface-based-observations/daily'],
#     'status': 'operational',
#     'id': '0-2000-0-86600'}},
#   {'id': '0-2000-0-86623',
#    'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-45.200833, -11.052222, 488.0]},
#    'properties': {'name': 'FORMOSA DO RIO PRETO',
#     'wigos_station_identifier': '0-2000-0-86623',
#     'traditional_station_identifier': '86623',
#     'barometer_height': 489.5,
#     'facility_type': 'landFixed',
#     'territory_name': 'BRA',
#     'wmo_region': 'southAmerica',
#     'url': 'https://oscar.wmo.int/surface/#/search/station/stationReportDetails/0-2000-0-86623',
#     'topic': 'origin/a/wis2/br-inmet/data/core/climate/surface-based-observations/daily',
#     'topics': ['origin/a/wis2/br-inmet/data/core/climate/surface-based-observations/daily'],
#     'status': 'operational',
#     'id': '0-2000-0-86623'}},
#   {'id': '0-2000-0-86640',
#    'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-38.444167, -11.058611, 182.0]},
#    'properties': {'name': 'RIBEIRA DO AMPARO',
#     'wigos_station_identifier': '0-2000-0-86640',
#     'traditional_station_identifier': '86640',
#     'barometer_height': 183.5,
#     'facility_type': 'landFixed',
#     'territory_name': 'BRA',
#     'wmo_region': 'southAmerica',
#     'url': 'https://oscar.wmo.int/surface/#/search/station/stationReportDetails/0-2000-0-86640',
#     'topic': 'origin/a/wis2/br-inmet/data/core/climate/surface-based-observations/daily',
#     'topics': ['origin/a/wis2/br-inmet/data/core/climate/surface-based-observations/daily'],
#     'status': 'operational',
#     'id': '0-2000-0-86640'}},
#   {'id': '0-2000-0-86740',
#    'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-43.843889, -16.686389, 645.87]},
#    'properties': {'name': 'MONTES CLAROS',
#     'wigos_station_identifier': '0-2000-0-86740',
#     'traditional_station_identifier': '86740',
#     'barometer_height': 647.37,
#     'facility_type': 'landFixed',
#     'territory_name': 'BRA',
#     'wmo_region': 'southAmerica',
#     'url': 'https://oscar.wmo.int/surface/#/search/station/stationReportDetails/0-2000-0-86740',
#     'topic': 'origin/a/wis2/br-inmet/data/core/climate/surface-based-observations/daily',
#     'topics': ['origin/a/wis2/br-inmet/data/core/climate/surface-based-observations/daily'],
#     'status': 'operational',
#     'id': '0-2000-0-86740'}},
#   {'id': '0-2000-0-86776',
#    'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-48.255556, -18.916944, 874.77]},
#    'properties': {'name': 'UBERLANDIA',
#     'wigos_station_identifier': '0-2000-0-86776',
#     'traditional_station_identifier': '86776',
#     'barometer_height': 876.27,
#     'facility_type': 'landFixed',
#     'territory_name': 'BRA',
#     'wmo_region': 'southAmerica',
#     'url': 'https://oscar.wmo.int/surface/#/search/station/stationReportDetails/0-2000-0-86776',
#     'topic': 'origin/a/wis2/br-inmet/data/core/climate/surface-based-observations/daily',
#     'topics': ['origin/a/wis2/br-inmet/data/core/climate/surface-based-observations/daily'],
#     'status': 'operational',
#     'id': '0-2000-0-86776'}},
#   {'id': '0-2000-0-86850',
#    'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-43.767778, -21.228333, 1168.76]},
#    'properties': {'name': 'BARBACENA',
#     'wigos_station_identifier': '0-2000-0-86850',
#     'traditional_station_identifier': '86850',
#     'barometer_height': 1170.26,
#     'facility_type': 'landFixed',
#     'territory_name': 'BRA',
#     'wmo_region': 'southAmerica',
#     'url': 'https://oscar.wmo.int/surface/#/search/station/stationReportDetails/0-2000-0-86850',
#     'topic': 'origin/a/wis2/br-inmet/data/core/climate/surface-based-observations/daily',
#     'topics': ['origin/a/wis2/br-inmet/data/core/climate/surface-based-observations/daily'],
#     'status': 'operational',
#     'id': '0-2000-0-86850'}},
#   {'id': '0-2000-0-86743',
#    'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-40.687778, -16.166667, 189.11]},
#    'properties': {'name': 'ALMENARA',
#     'wigos_station_identifier': '0-2000-0-86743',
#     'traditional_station_identifier': '86743',
#     'barometer_height': 190.61,
#     'facility_type': 'landFixed',
#     'territory_name': 'BRA',
#     'wmo_region': 'southAmerica',
#     'url': 'https://oscar.wmo.int/surface/#/search/station/stationReportDetails/0-2000-0-86743',
#     'topic': 'origin/a/wis2/br-inmet/data/core/climate/surface-based-observations/daily',
#     'topics': ['origin/a/wis2/br-inmet/data/core/climate/surface-based-observations/daily'],
#     'status': 'operational',
#     'id': '0-2000-0-86743'}}],
#  'numberMatched': 1458,
#  'numberReturned': 1000,
#  'links': [{'type': 'application/geo+json',
#    'rel': 'self',
#    'title': 'This document as GeoJSON',
#    'href': 'https://wis2bra.inmet.gov.br/oapi/collections/stations/items?f=json&limit=1000'},
#   {'rel': 'alternate',
#    'type': 'application/ld+json',
#    'title': 'This document as RDF (JSON-LD)',
#    'href': 'https://wis2bra.inmet.gov.br/oapi/collections/stations/items?f=jsonld&limit=1000'},
#   {'type': 'text/html',
#    'rel': 'alternate',
#    'title': 'This document as HTML',
#    'href': 'https://wis2bra.inmet.gov.br/oapi/collections/stations/items?f=html&limit=1000'},
#   {'type': 'text/csv; charset=utf-8',
#    'rel': 'alternate',
#    'title': 'This document as CSV',
#    'href': 'https://wis2bra.inmet.gov.br/oapi/collections/stations/items?f=csv&limit=1000'},
#   {'type': 'application/geo+json',
#    'rel': 'next',
#    'title': 'Items (next)',
#    'href': 'https://wis2bra.inmet.gov.br/oapi/collections/stations/items?f=json&offset=1000&limit=1000'},
#   {'type': 'application/json',
#    'title': 'Stations',
#    'rel': 'collection',
#    'href': 'https://wis2bra.inmet.gov.br/oapi/collections/stations'}],
#  'timeStamp': '2026-08-23T21:41:08.415546Z'}

# %%
import requests
from datetime import datetime, timezone, timedelta

url = "https://wis2bra.inmet.gov.br/oapi/collections/urn:wmo:md:br-inmet:synop/items"

agora = datetime.now(timezone.utc)
inicio = agora - timedelta(hours=2)
parametros = {"f": "json", "limit": 100, "datetime": f"{inicio.isoformat()}/{agora.isoformat()}"}

resposta = requests.get(url, params=parametros, timeout=30)
resposta.raise_for_status()
dados = resposta.json()

# %%
temperaturas = []

for obs in dados["features"]:

    prop = obs["properties"]

    if prop["name"] == "air_temperature":

        temperatura = {
            "name": prop["name"],
            "value": prop["value"],
            "units": prop["units"],
            "phenomenonTime": prop["phenomenonTime"],
            "wigos_station_identifier":
                prop["wigos_station_identifier"]
        }

        temperaturas.append(temperatura)

# %%
capitais = [
    'BRASILIA', 'GOIANIA', 'CUIABA', 'CAMPO GRANDE',
    'MACEIO', 'SALVADOR', 'FORTALEZA', 'SAO LUIS',
    'JOAO PESSOA', 'RECIFE', 'TERESINA', 'NATAL',
    'ARACAJU', 'RIO BRANCO', 'MACAPA', 'MANAUS',
    'BELEM', 'PORTO VELHO', 'BOA VISTA', 'PALMAS',
    'VITORIA', 'BELO HORIZONTE', 'RIO DE JANEIRO',
    'SAO PAULO', 'CURITIBA', 'PORTO ALEGRE',
    'FLORIANOPOLIS'
]

# ---------------------------------------------------------
# 1. Localizar estações das capitais
# ---------------------------------------------------------
estacoes_capitais = {}
for estacao in estacoes:
    nome = estacao["nome"].upper()
    for capital in capitais:
        if capital in nome:
            estacoes_capitais[estacao["wigos"]] = {
                "capital": capital,
                "nome_estacao": estacao["nome"],
                "longitude": estacao["longitude"],
                "latitude": estacao["latitude"],
                "altitude": estacao["altitude"]
            }

# %%
# ---------------------------------------------------------
# 2. Localizar temperaturas dessas estações
# ---------------------------------------------------------

temperaturas = []

for obs in dados["features"]:
    prop = obs["properties"]
    wigos = prop["wigos_station_identifier"]
    if (prop["name"] == "air_temperature" and wigos in estacoes_capitais):
        estacao = estacoes_capitais[wigos]
        temperatura = {
            "capital": estacao["capital"],
            "estacao": estacao["nome_estacao"],
            "temperatura": prop["value"],
            "unidade": prop["units"],
            "dt_referencia": prop["phenomenonTime"],
            "wigos": wigos
        }

        temperaturas.append(temperatura)

# %%
for temperatura in temperaturas:
    print(temperatura)
