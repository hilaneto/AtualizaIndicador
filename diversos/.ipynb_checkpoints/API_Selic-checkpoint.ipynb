# %%
import requests
# import pandas as pd

from datetime import datetime, timedelta

# %%
import sys
import os

root = os.path.abspath(os.path.join(os.getcwd(), "../"))

if root not in sys.path:
    sys.path.insert(0, root)

print(root)
# Out:
# /home/hilaneto/Jhan/Desenvolvimento/Python/Projetos/AtualizaIndicador

# %%
# Datas -------------------------------------------------------
hoje = datetime.now()

data_inicial = (hoje - timedelta(days=62)).strftime("%d/%m/%Y")
data_final = hoje.strftime("%d/%m/%Y")

print(f"Período: {data_inicial} até {data_final}")
# Out:
# Período: 21/06/2026 até 22/08/2026

# %%
# https://api.bcb.gov.br/dados/serie/bcdata.sgs.10844/dados?formato=json&dataInicial=25/06/2026&dataFinal=18/08/2026

# API Banco Central -------------------------------------------
url = "https://api.bcb.gov.br/dados/serie/bcdata.sgs.432/dados"

parametros = { "formato": "json", "dataInicial": data_inicial, "dataFinal": data_final }

resposta = requests.get(url, params=parametros, timeout=10)
resposta.raise_for_status()
dados = resposta.json() # lista de dicionários

# Percorrer a lista de dicionário
for selic in dados:
    print(selic)
# Out:
# {'data': '21/06/2026', 'valor': '14.25'}
# {'data': '22/06/2026', 'valor': '14.25'}
# {'data': '23/06/2026', 'valor': '14.25'}
# {'data': '24/06/2026', 'valor': '14.25'}
# {'data': '25/06/2026', 'valor': '14.25'}
# {'data': '26/06/2026', 'valor': '14.25'}
# {'data': '27/06/2026', 'valor': '14.25'}
# {'data': '28/06/2026', 'valor': '14.25'}
# {'data': '29/06/2026', 'valor': '14.25'}
# {'data': '30/06/2026', 'valor': '14.25'}
# {'data': '01/07/2026', 'valor': '14.25'}
# {'data': '02/07/2026', 'valor': '14.25'}
# {'data': '03/07/2026', 'valor': '14.25'}
# {'data': '04/07/2026', 'valor': '14.25'}
# {'data': '05/07/2026', 'valor': '14.25'}
# {'data': '06/07/2026', 'valor': '14.25'}
# {'data': '07/07/2026', 'valor': '14.25'}
# {'data': '08/07/2026', 'valor': '14.25'}
# {'data': '09/07/2026', 'valor': '14.25'}
# {'data': '10/07/2026', 'valor': '14.25'}
# {'data': '11/07/2026', 'valor': '14.25'}
# {'data': '12/07/2026', 'valor': '14.25'}
# {'data': '13/07/2026', 'valor': '14.25'}
# {'data': '14/07/2026', 'valor': '14.25'}
# {'data': '15/07/2026', 'valor': '14.25'}
# {'data': '16/07/2026', 'valor': '14.25'}
# {'data': '17/07/2026', 'valor': '14.25'}
# {'data': '18/07/2026', 'valor': '14.25'}
# {'data': '19/07/2026', 'valor': '14.25'}
# {'data': '20/07/2026', 'valor': '14.25'}
# {'data': '21/07/2026', 'valor': '14.25'}
# {'data': '22/07/2026', 'valor': '14.25'}
# {'data': '23/07/2026', 'valor': '14.25'}
# {'data': '24/07/2026', 'valor': '14.25'}
# {'data': '25/07/2026', 'valor': '14.25'}
# {'data': '26/07/2026', 'valor': '14.25'}
# {'data': '27/07/2026', 'valor': '14.25'}
# {'data': '28/07/2026', 'valor': '14.25'}
# {'data': '29/07/2026', 'valor': '14.25'}
# {'data': '30/07/2026', 'valor': '14.25'}
# {'data': '31/07/2026', 'valor': '14.25'}
# {'data': '01/08/2026', 'valor': '14.25'}
# {'data': '02/08/2026', 'valor': '14.25'}
# {'data': '03/08/2026', 'valor': '14.25'}
# {'data': '04/08/2026', 'valor': '14.25'}
# {'data': '05/08/2026', 'valor': '14.25'}
# {'data': '06/08/2026', 'valor': '14.00'}
# {'data': '07/08/2026', 'valor': '14.00'}
# {'data': '08/08/2026', 'valor': '14.00'}
# {'data': '09/08/2026', 'valor': '14.00'}
# {'data': '10/08/2026', 'valor': '14.00'}
# {'data': '11/08/2026', 'valor': '14.00'}
# {'data': '12/08/2026', 'valor': '14.00'}
# {'data': '13/08/2026', 'valor': '14.00'}
# {'data': '14/08/2026', 'valor': '14.00'}
# {'data': '15/08/2026', 'valor': '14.00'}
# {'data': '16/08/2026', 'valor': '14.00'}
# {'data': '17/08/2026', 'valor': '14.00'}
# {'data': '18/08/2026', 'valor': '14.00'}
# {'data': '19/08/2026', 'valor': '14.00'}
# {'data': '20/08/2026', 'valor': '14.00'}
# {'data': '21/08/2026', 'valor': '14.00'}
# {'data': '22/08/2026', 'valor': '14.00'}

# %%
for selic in dados:
    print(selic["data"], selic["valor"])
# Out:
# 21/06/2026 14.25
# 22/06/2026 14.25
# 23/06/2026 14.25
# 24/06/2026 14.25
# 25/06/2026 14.25
# 26/06/2026 14.25
# 27/06/2026 14.25
# 28/06/2026 14.25
# 29/06/2026 14.25
# 30/06/2026 14.25
# 01/07/2026 14.25
# 02/07/2026 14.25
# 03/07/2026 14.25
# 04/07/2026 14.25
# 05/07/2026 14.25
# 06/07/2026 14.25
# 07/07/2026 14.25
# 08/07/2026 14.25
# 09/07/2026 14.25
# 10/07/2026 14.25
# 11/07/2026 14.25
# 12/07/2026 14.25
# 13/07/2026 14.25
# 14/07/2026 14.25
# 15/07/2026 14.25
# 16/07/2026 14.25
# 17/07/2026 14.25
# 18/07/2026 14.25
# 19/07/2026 14.25
# 20/07/2026 14.25
# 21/07/2026 14.25
# 22/07/2026 14.25
# 23/07/2026 14.25
# 24/07/2026 14.25
# 25/07/2026 14.25
# 26/07/2026 14.25
# 27/07/2026 14.25
# 28/07/2026 14.25
# 29/07/2026 14.25
# 30/07/2026 14.25
# 31/07/2026 14.25
# 01/08/2026 14.25
# 02/08/2026 14.25
# 03/08/2026 14.25
# 04/08/2026 14.25
# 05/08/2026 14.25
# 06/08/2026 14.00
# 07/08/2026 14.00
# 08/08/2026 14.00
# 09/08/2026 14.00
# 10/08/2026 14.00
# 11/08/2026 14.00
# 12/08/2026 14.00
# 13/08/2026 14.00
# 14/08/2026 14.00
# 15/08/2026 14.00
# 16/08/2026 14.00
# 17/08/2026 14.00
# 18/08/2026 14.00
# 19/08/2026 14.00
# 20/08/2026 14.00
# 21/08/2026 14.00
# 22/08/2026 14.00

# %%
from database.conexao import conectar
from indicadores.selic import Selic
from decimal import Decimal

dados_selic = []

with conectar():
    
    for registro in dados:
        selic = {"indice": Decimal(registro["valor"]),
                "status": True,
                "dt_referencia": datetime.strptime(registro["data"],"%d/%m/%Y").date(),
                "dt_atualizacao": datetime.now()}
        dados_selic.append(selic)
        
        Selic.insert(**selic).on_conflict(
        conflict_target=[Selic.dt_referencia],
        update={Selic.indice: selic["indice"],
                Selic.status: selic["status"],
                Selic.dt_atualizacao: selic["dt_atualizacao"]}).execute()

# %%
from database.conexao import conectar
from indicadores.selic import Selic

with conectar():
    dados_selic = Selic.buscar()
    print(dados_selic)
# Out:
# [{'data': '21/06/2026', 'valor': '14.25'}, {'data': '22/06/2026', 'valor': '14.25'}, {'data': '23/06/2026', 'valor': '14.25'}, {'data': '24/06/2026', 'valor': '14.25'}, {'data': '25/06/2026', 'valor': '14.25'}, {'data': '26/06/2026', 'valor': '14.25'}, {'data': '27/06/2026', 'valor': '14.25'}, {'data': '28/06/2026', 'valor': '14.25'}, {'data': '29/06/2026', 'valor': '14.25'}, {'data': '30/06/2026', 'valor': '14.25'}, {'data': '01/07/2026', 'valor': '14.25'}, {'data': '02/07/2026', 'valor': '14.25'}, {'data': '03/07/2026', 'valor': '14.25'}, {'data': '04/07/2026', 'valor': '14.25'}, {'data': '05/07/2026', 'valor': '14.25'}, {'data': '06/07/2026', 'valor': '14.25'}, {'data': '07/07/2026', 'valor': '14.25'}, {'data': '08/07/2026', 'valor': '14.25'}, {'data': '09/07/2026', 'valor': '14.25'}, {'data': '10/07/2026', 'valor': '14.25'}, {'data': '11/07/2026', 'valor': '14.25'}, {'data': '12/07/2026', 'valor': '14.25'}, {'data': '13/07/2026', 'valor': '14.25'}, {'data': '14/07/2026', 'valor': '14.25'}, {'data': '15/07/2026', 'valor': '14.25'}, {'data': '16/07/2026', 'valor': '14.25'}, {'data': '17/07/2026', 'valor': '14.25'}, {'data': '18/07/2026', 'valor': '14.25'}, {'data': '19/07/2026', 'valor': '14.25'}, {'data': '20/07/2026', 'valor': '14.25'}, {'data': '21/07/2026', 'valor': '14.25'}, {'data': '22/07/2026', 'valor': '14.25'}, {'data': '23/07/2026', 'valor': '14.25'}, {'data': '24/07/2026', 'valor': '14.25'}, {'data': '25/07/2026', 'valor': '14.25'}, {'data': '26/07/2026', 'valor': '14.25'}, {'data': '27/07/2026', 'valor': '14.25'}, {'data': '28/07/2026', 'valor': '14.25'}, {'data': '29/07/2026', 'valor': '14.25'}, {'data': '30/07/2026', 'valor': '14.25'}, {'data': '31/07/2026', 'valor': '14.25'}, {'data': '01/08/2026', 'valor': '14.25'}, {'data': '02/08/2026', 'valor': '14.25'}, {'data': '03/08/2026', 'valor': '14.25'}, {'data': '04/08/2026', 'valor': '14.25'}, {'data': '05/08/2026', 'valor': '14.25'}, {'data': '06/08/2026', 'valor': '14.00'}, {'data': '07/08/2026', 'valor': '14.00'}, {'data': '08/08/2026', 'valor': '14.00'}, {'data': '09/08/2026', 'valor': '14.00'}, {'data': '10/08/2026', 'valor': '14.00'}, {'data': '11/08/2026', 'valor': '14.00'}, {'data': '12/08/2026', 'valor': '14.00'}, {'data': '13/08/2026', 'valor': '14.00'}, {'data': '14/08/2026', 'valor': '14.00'}, {'data': '15/08/2026', 'valor': '14.00'}, {'data': '16/08/2026', 'valor': '14.00'}, {'data': '17/08/2026', 'valor': '14.00'}, {'data': '18/08/2026', 'valor': '14.00'}, {'data': '19/08/2026', 'valor': '14.00'}, {'data': '20/08/2026', 'valor': '14.00'}, {'data': '21/08/2026', 'valor': '14.00'}, {'data': '22/08/2026', 'valor': '14.00'}]

# %%
from database.conexao import conectar
from indicadores.selic import Selic

aa = Selic.atualizar_selic()

print(aa)
# Out:
# None
