# %%
import requests
# import pandas as pd

from datetime import datetime, timedelta

# %%
import sys
import os

root = os.path.abspath(os.path.join(os.getcwd(), "../"))

if root not in sys.path:
    sys.path.insert(0, root)

print(root)
# Out:
# /home/hilaneto/Jhan/Desenvolvimento/Python/Projetos/AtualizaIndicador

# %%
# Datas -------------------------------------------------------
hoje = datetime.now()
data_inicial = (hoje - timedelta(days=62)).strftime("%d/%m/%Y")
data_final = hoje.strftime("%d/%m/%Y")

print(f"Período: {data_inicial} até {data_final}")
# Out:
# Período: 19/06/2026 até 20/08/2026

# %%
import requests
from datetime import datetime, timedelta

url = "https://api.bcb.gov.br/dados/serie/bcdata.sgs.1/dados"

parametros = { "formato": "json", "dataInicial": data_inicial, "dataFinal": data_final }

resposta = requests.get( url, params=parametros, timeout=10)

resposta.raise_for_status()

dados = resposta.json()

dados
# Out:
# [{'data': '19/06/2026', 'valor': '5.1442'},
#  {'data': '22/06/2026', 'valor': '5.1395'},
#  {'data': '23/06/2026', 'valor': '5.1743'},
#  {'data': '24/06/2026', 'valor': '5.2098'},
#  {'data': '25/06/2026', 'valor': '5.1892'},
#  {'data': '26/06/2026', 'valor': '5.1695'},
#  {'data': '29/06/2026', 'valor': '5.1717'},
#  {'data': '30/06/2026', 'valor': '5.1766'},
#  {'data': '01/07/2026', 'valor': '5.1950'},
#  {'data': '02/07/2026', 'valor': '5.1945'},
#  {'data': '03/07/2026', 'valor': '5.1717'},
#  {'data': '06/07/2026', 'valor': '5.1670'},
#  {'data': '07/07/2026', 'valor': '5.1458'},
#  {'data': '08/07/2026', 'valor': '5.1552'},
#  {'data': '09/07/2026', 'valor': '5.1329'},
#  {'data': '10/07/2026', 'valor': '5.1088'},
#  {'data': '13/07/2026', 'valor': '5.1183'},
#  {'data': '14/07/2026', 'valor': '5.0742'},
#  {'data': '15/07/2026', 'valor': '5.0727'},
#  {'data': '16/07/2026', 'valor': '5.0975'},
#  {'data': '17/07/2026', 'valor': '5.1176'},
#  {'data': '20/07/2026', 'valor': '5.0894'},
#  {'data': '21/07/2026', 'valor': '5.0780'},
#  {'data': '22/07/2026', 'valor': '5.0638'},
#  {'data': '23/07/2026', 'valor': '5.0807'},
#  {'data': '24/07/2026', 'valor': '5.0666'},
#  {'data': '27/07/2026', 'valor': '5.1005'},
#  {'data': '28/07/2026', 'valor': '5.1177'},
#  {'data': '29/07/2026', 'valor': '5.1217'},
#  {'data': '30/07/2026', 'valor': '5.0739'},
#  {'data': '31/07/2026', 'valor': '5.0773'},
#  {'data': '03/08/2026', 'valor': '5.0723'},
#  {'data': '04/08/2026', 'valor': '5.1053'},
#  {'data': '05/08/2026', 'valor': '5.1154'},
#  {'data': '06/08/2026', 'valor': '5.1017'},
#  {'data': '07/08/2026', 'valor': '5.0908'},
#  {'data': '10/08/2026', 'valor': '5.0963'},
#  {'data': '11/08/2026', 'valor': '5.1285'},
#  {'data': '12/08/2026', 'valor': '5.1639'},
#  {'data': '13/08/2026', 'valor': '5.1859'},
#  {'data': '14/08/2026', 'valor': '5.2236'},
#  {'data': '17/08/2026', 'valor': '5.2014'},
#  {'data': '18/08/2026', 'valor': '5.2043'},
#  {'data': '19/08/2026', 'valor': '5.1714'},
#  {'data': '20/08/2026', 'valor': '5.1862'}]

# %%
for dolar in dados:
    print(dolar["data"], dolar["valor"])

# %%
from database.conexao import conectar
from indicadores.dolar import Dolar
from decimal import Decimal

dados_dolar = []

with conectar():
    
    for registro in dados:
        dolar = {"valor": Decimal(registro["valor"]),
                "status": True,
                "dt_referencia": datetime.strptime(registro["data"],"%d/%m/%Y").date(),
                "dt_atualizacao": datetime.now()}
        dados_dolar.append(dolar)
        
        Dolar.insert(**dolar).on_conflict(
        conflict_target=[Dolar.dt_referencia],
        update={Dolar.valor: dolar["valor"],
                Dolar.status: dolar["status"],
                Dolar.dt_atualizacao: dolar["dt_atualizacao"]}).execute()

# %%
from database.conexao import conectar
from indicadores.dolar import Dolar

aa = Dolar.atualizar_dolar()

print(aa)
