# %%
import requests
# import pandas as pd

from datetime import datetime, timedelta

# %%
import sys
import os

root = os.path.abspath(os.path.join(os.getcwd(), "../"))

if root not in sys.path:
    sys.path.insert(0, root)

print(root)
# Out:
# /home/hilaneto/Jhan/Desenvolvimento/Python/Projetos/AtualizaIndicador

# %%
# Datas -------------------------------------------------------
hoje = datetime.now()

data_inicial = (hoje - timedelta(days=60)).strftime("%d/%m/%Y")
data_final = hoje.strftime("%d/%m/%Y")

print(f"Período: {data_inicial} até {data_final}")
# Out:
# Período: 24/06/2026 até 23/08/2026

# %%
# https://api.bcb.gov.br/dados/serie/bcdata.sgs.10844/dados?formato=json&dataInicial=25/06/2026&dataFinal=18/08/2026

# API Banco Central --------------------------------------------
url = "https://api.bcb.gov.br/dados/serie/bcdata.sgs.1619/dados"

parametros = { "formato": "json", "dataInicial": data_inicial, "dataFinal": data_final }

resposta = requests.get(url, params=parametros, timeout=30)
resposta.raise_for_status()
dados = resposta.json() # lista de dicionários

# Percorrer a lista de dicionário
for salario in dados:
    print(salario)
# Out:
# {'data': '01/06/2026', 'valor': '1621.00'}
# {'data': '01/07/2026', 'valor': '1621.00'}
# {'data': '01/08/2026', 'valor': '1621.00'}

# %%
for salario in dados:
    print(salario["data"], salario["valor"])
# Out:
# 01/06/2026 1621.00
# 01/07/2026 1621.00
# 01/08/2026 1621.00

# %%
from database.conexao import conectar
from indicadores.salario import Salario
from decimal import Decimal

dados_salario = []

with conectar():
    for registro in dados:
        salario = {"vl_salario": Decimal(registro["valor"]),
                   "status": True,
                   "dt_referencia": datetime.strptime(registro["data"], "%d/%m/%Y").date(),"dt_atualizacao": datetime.now()
                  }
        (Salario.insert(**salario).on_conflict(conflict_target=[Salario.vl_salario],action="IGNORE").execute())
# Out:
# ---------------------------------------------------------------------------
# InvalidColumnReference                    Traceback (most recent call last)
# File ~/.pyenv/versions/3.14.3/lib/python3.14/site-packages/peewee.py:3813, in Database.execute_sql(self, sql, params)
#    3812     cursor = self.cursor()
# -> 3813     cursor.execute(sql, params or ())
#    3814 return cursor
#
# File ~/.pyenv/versions/3.14.3/lib/python3.14/site-packages/psycopg/cursor.py:117, in Cursor.execute(self, query, params, prepare, binary)
#     116 except e._NO_TRACEBACK as ex:
# --> 117     raise ex.with_traceback(None)
#     118 return self
#
# InvalidColumnReference: there is no unique or exclusion constraint matching the ON CONFLICT specification
#
# During handling of the above exception, another exception occurred:
#
# ProgrammingError                          Traceback (most recent call last)
# Cell In[6], line 20
#      16         Salario.insert(**salario).on_conflict(
#      17         conflict_target=[Salario.dt_referencia],
#      18         update={Salario.vl_salario: salario["vl_salario"],
#      19                 Salario.status: salario["status"],
# ---> 20                 Salario.dt_atualizacao: salario["dt_atualizacao"]}).execute()
#
# File ~/.pyenv/versions/3.14.3/lib/python3.14/site-packages/peewee.py:2105, in database_required.<locals>.inner(self, database, *args, **kwargs)
#    2102 if not database:
#    2103     raise InterfaceError('Query must be bound to a database in order '
#    2104                          'to call "%s".' % method.__name__)
# -> 2105 return method(self, database, *args, **kwargs)
#
# File ~/.pyenv/versions/3.14.3/lib/python3.14/site-packages/peewee.py:2172, in BaseQuery.execute(self, database)
#    2170 @database_required
#    2171 def execute(self, database):
# -> 2172     return self._execute(database)
#
# File ~/.pyenv/versions/3.14.3/lib/python3.14/site-packages/peewee.py:2992, in Insert._execute(self, database)
#    2990     self._row_type = ROW.TUPLE
#    2991 try:
# -> 2992     return super(Insert, self)._execute(database)
#    2993 except self.DefaultValuesException:
#    2994     pass
#
# File ~/.pyenv/versions/3.14.3/lib/python3.14/site-packages/peewee.py:2705, in _WriteQuery._execute(self, database)
#    2703 def _execute(self, database):
#    2704     if self._returning:
# -> 2705         cursor = self.execute_returning(database)
#    2706     else:
#    2707         cursor = database.execute(self)
#
# File ~/.pyenv/versions/3.14.3/lib/python3.14/site-packages/peewee.py:2711, in _WriteQuery.execute_returning(self, database)
#    2710 def execute_returning(self, database):
# -> 2711     return super(_WriteQuery, self)._execute(database)
#
# File ~/.pyenv/versions/3.14.3/lib/python3.14/site-packages/peewee.py:2183, in BaseQuery._execute(self, database)
#    2181 def _execute(self, database):
#    2182     if self._cursor_wrapper is None:
# -> 2183         cursor = database.execute(self)
#    2184         self._cursor_wrapper = self._get_cursor_wrapper(cursor)
#    2185     return self._cursor_wrapper
#
# File ~/.pyenv/versions/3.14.3/lib/python3.14/site-packages/peewee.py:3819, in Database.execute(self, query, **context_options)
#    3817 ctx = self.get_sql_context(**context_options)
#    3818 sql, params = ctx.sql(query).query()
# -> 3819 return self.execute_sql(sql, params)
#
# File ~/.pyenv/versions/3.14.3/lib/python3.14/site-packages/peewee.py:3811, in Database.execute_sql(self, sql, params)
#    3809 if logger.isEnabledFor(logging.DEBUG):
#    3810     logger.debug((sql, params))
# -> 3811 with __exception_wrapper__:
#    3812     cursor = self.cursor()
#    3813     cursor.execute(sql, params or ())
#
# File ~/.pyenv/versions/3.14.3/lib/python3.14/site-packages/peewee.py:3564, in ExceptionWrapper.__exit__(self, exc_type, exc_value, traceback)
#    3562 new_type = self.exceptions[exc_type.__name__]
#    3563 exc_args = exc_value.args
# -> 3564 raise new_type(exc_value, *exc_args).with_traceback(traceback)
#
# File ~/.pyenv/versions/3.14.3/lib/python3.14/site-packages/peewee.py:3813, in Database.execute_sql(self, sql, params)
#    3811 with __exception_wrapper__:
#    3812     cursor = self.cursor()
# -> 3813     cursor.execute(sql, params or ())
#    3814 return cursor
#
# File ~/.pyenv/versions/3.14.3/lib/python3.14/site-packages/psycopg/cursor.py:117, in Cursor.execute(self, query, params, prepare, binary)
#     113         self._conn.wait(
#     114             self._execute_gen(query, params, prepare=prepare, binary=binary)
#     115         )
#     116 except e._NO_TRACEBACK as ex:
# --> 117     raise ex.with_traceback(None)
#     118 return self
#
# ProgrammingError: there is no unique or exclusion constraint matching the ON CONFLICT specification

# %%
from database.conexao import conectar
from indicadores.salario import Salario

with conectar():
    dados_salario = Salario.buscar()
    print(dados_salario

# %%
from database.conexao import conectar
from indicadores.salario import Salario

aa = Salario.atualizar_salario()

print(aa)
