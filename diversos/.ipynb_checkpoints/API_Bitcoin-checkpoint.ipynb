# %%
import requests

from datetime import datetime, timedelta

# %%
import sys
import os

root = os.path.abspath(os.path.join(os.getcwd(), "../"))

if root not in sys.path:
    sys.path.insert(0, root)

print(root)
# Out:
# /home/hilaneto/Jhan/Desenvolvimento/Python/Projetos/AtualizaIndicador

# %%
# Datas -------------------------------------------------------
hoje = datetime.now()
data_inicial = (hoje - timedelta(days=62)).strftime("%d/%m/%Y")
data_final = hoje.strftime("%d/%m/%Y")

hoje = datetime.now().strftime("%m-%d-%Y")

print(f"Período: {data_inicial} até {data_final}")

print(hoje)

# %% [markdown]
# ##### Busca Bitcoin - Código VSCode - Awesomeapi

# %%
import os
import requests
from dotenv import load_dotenv

load_dotenv()
AWESOME_API_KEY = os.getenv("AWESOME_API_KEY")

url = "https://economia.awesomeapi.com.br/json/last/BTC-BRL"
headers = {"x-api-key": AWESOME_API_KEY}
resposta = requests.get(url, headers=headers, timeout=10)
resposta.raise_for_status()
dolar = resposta.json()["BTCBRL"]

print(dolar)
print("Compra:", dolar["bid"])
print("Venda:", dolar["ask"])
print("Variação:", dolar["pctChange"])
print("Data/hora:", dolar["create_date"])
# Out:
# {'code': 'BTC', 'codein': 'BRL', 'name': 'Bitcoin/Real Brasileiro', 'high': '407223', 'low': '395426', 'varBid': '-3824', 'pctChange': '-0.95', 'bid': '398761', 'ask': '398762', 'timestamp': '1787448190', 'create_date': '2026-08-22 22:23:10'}
# Compra: 398761
# Venda: 398762
# Variação: -0.95
# Data/hora: 2026-08-22 22:23:10

# %% [markdown]
# ##### Busca Dolar - AwesomeApi

# %%
from database.conexao import conectar
from indicadores.bitcoin import Bitcoin

dados = Bitcoin.buscar()

print(dados)
# Out:
# {'BTCBRL': {'code': 'BTC', 'codein': 'BRL', 'name': 'Bitcoin/Real Brasileiro', 'high': '407223', 'low': '395426', 'varBid': '-3824', 'pctChange': '-0.95', 'bid': '398761', 'ask': '398762', 'timestamp': '1787448190', 'create_date': '2026-08-22 22:23:10'}}

# %%
from indicadores.bitcoin import Bitcoin

dados = Bitcoin.buscar()
print(dados)
# Out:
# {'BTCBRL': {'code': 'BTC', 'codein': 'BRL', 'name': 'Bitcoin/Real Brasileiro', 'high': '407223', 'low': '395426', 'varBid': '-3824', 'pctChange': '-0.95', 'bid': '398761', 'ask': '398762', 'timestamp': '1787448190', 'create_date': '2026-08-22 22:23:10'}}

# %% [markdown]
# ##### Tratar Dados

# %%
from database.conexao import conectar
from indicadores.bitcoin import Bitcoin

aa = Bitcoin.tratar_dados(dados)

print(aa)
# Out:
# {'valor': Decimal('398761'), 'status': True, 'moeda': 'BTC', 'dt_referencia': datetime.datetime(2026, 8, 22, 22, 23, 10), 'dt_atualizacao': datetime.datetime(2026, 8, 22, 22, 24, 29, 132310)}

# %% [markdown]
# ##### Atualizar tb_dolar no Banco

# %%
from database.conexao import conectar
from indicadores.bitcoin import Bitcoin

aa = Bitcoin.atualizar_bitcoin()

# %% [markdown]
# #### API Banco Central

# %%
# resposta = requests.get("https://olinda.bcb.gov.br/olinda/servico/PTAX/versao/v1/odata/CotacaoMoedaDia(moeda='USD',dataCotacao='08-21-2026')")

hoje = datetime.now().strftime("%m-%d-%Y")

url = ("https://olinda.bcb.gov.br/olinda/servico/PTAX/versao/v1/odata/CotacaoMoedaDia(moeda=@moeda,dataCotacao=@dataCotacao)")

parametros = { "@moeda": "'USD'", "@dataCotacao": f"'{hoje}'", "$format": "json" }

resposta = requests.get( url, params=parametros, timeout=10 )

resposta.raise_for_status()

dados = resposta.json()

dados
