# %%
import requests

from datetime import datetime, timezone, timedelta

# %%
# Capital -> Região
capitais_regioes = {
    "BRASILIA": "Centro-Oeste",
    "GOIANIA": "Centro-Oeste",
    "CUIABA": "Centro-Oeste",
    "CAMPO GRANDE": "Centro-Oeste",

    "MACEIO": "Nordeste",
    "SALVADOR": "Nordeste",
    "FORTALEZA": "Nordeste",
    "SAO LUIS": "Nordeste",
    "JOAO PESSOA": "Nordeste",
    "RECIFE": "Nordeste",
    "TERESINA": "Nordeste",
    "NATAL": "Nordeste",
    "ARACAJU": "Nordeste",

    "RIO BRANCO": "Norte",
    "MACAPA": "Norte",
    "MANAUS": "Norte",
    "BELEM": "Norte",
    "PORTO VELHO": "Norte",
    "BOA VISTA": "Norte",
    "PALMAS": "Norte",

    "VITORIA": "Sudeste",
    "BELO HORIZONTE": "Sudeste",
    "RIO DE JANEIRO": "Sudeste",
    "SAO PAULO": "Sudeste",

    "CURITIBA": "Sul",
    "PORTO ALEGRE": "Sul",
    "FLORIANOPOLIS": "Sul"
}

# %%
url = "https://wis2bra.inmet.gov.br/oapi/collections/stations/items"

todas_estacoes = []

while url:
    resposta = requests.get(url, params={"f": "json", "limit": 1000}, timeout=30)
    resposta.raise_for_status()
    dados = resposta.json()
    todas_estacoes.extend(dados["features"])
    url = next( (link["href"]
                for link in dados.get("links", [])
                if link.get("rel") == "next"),None
              )

estacoes_capitais = {}

for estacao in todas_estacoes:

    prop = estacao["properties"]
    nome = prop["name"].upper()

    for cidade, regiao in capitais_regioes.items():
        if cidade in nome:
            estacoes_capitais[prop["wigos_station_identifier"]] = {"cidade": cidade, "regiao": regiao}

# %%
url = ("https://wis2bra.inmet.gov.br/oapi/collections/urn:wmo:md:br-inmet:synop/items")

agora = datetime.now(timezone.utc)
inicio = agora - timedelta(hours=6)

todas_observacoes = []

parametros = {"f": "json", "limit": 1000, "datetime": f"{inicio.isoformat()}/{agora.isoformat()}"}

while url:
    resposta = requests.get(url, params=parametros, timeout=30)
    resposta.raise_for_status()
    dados = resposta.json()
    todas_observacoes.extend(dados["features"])

    url = next( (link["href"]
                for link in dados.get("links", [])
                if link.get("rel") == "next" ), None
              )

    parametros = None

# %%
temperaturas = []

for obs in todas_observacoes:
    prop = obs["properties"]
    wigos = prop["wigos_station_identifier"]
    if (prop["name"] == "air_temperature" and wigos in estacoes_capitais):
        temperaturas.append({
            "regiao": estacoes_capitais[wigos]["regiao"],
            "cidade": estacoes_capitais[wigos]["cidade"],
            "temperatura": prop["value"],
            "dt_referencia": prop["phenomenonTime"]
        })

# %%
for temperatura in temperaturas:
    print(temperatura)
# Out:
# {'regiao': 'Norte', 'cidade': 'MANAUS', 'temperatura': 32.6, 'dt_referencia': '2026-08-23T18:00:00Z'}
# {'regiao': 'Norte', 'cidade': 'MACAPA', 'temperatura': 32.5, 'dt_referencia': '2026-08-23T18:00:00Z'}
# {'regiao': 'Norte', 'cidade': 'PALMAS', 'temperatura': 37.7, 'dt_referencia': '2026-08-23T18:00:00Z'}
# {'regiao': 'Nordeste', 'cidade': 'SAO LUIS', 'temperatura': 31.4, 'dt_referencia': '2026-08-23T18:00:00Z'}
# {'regiao': 'Centro-Oeste', 'cidade': 'CUIABA', 'temperatura': 35.9, 'dt_referencia': '2026-08-23T18:00:00Z'}
# {'regiao': 'Centro-Oeste', 'cidade': 'CAMPO GRANDE', 'temperatura': 28.2, 'dt_referencia': '2026-08-23T19:00:00Z'}
# {'regiao': 'Sudeste', 'cidade': 'SAO PAULO', 'temperatura': 21.8, 'dt_referencia': '2026-08-23T19:00:00Z'}
# {'regiao': 'Sudeste', 'cidade': 'BELO HORIZONTE', 'temperatura': 27.5, 'dt_referencia': '2026-08-23T18:00:00Z'}
# {'regiao': 'Sudeste', 'cidade': 'RIO DE JANEIRO', 'temperatura': 12.7, 'dt_referencia': '2026-08-23T19:00:00Z'}
# {'regiao': 'Sudeste', 'cidade': 'RIO DE JANEIRO', 'temperatura': 21.8, 'dt_referencia': '2026-08-23T19:00:00Z'}
# {'regiao': 'Sudeste', 'cidade': 'BELO HORIZONTE', 'temperatura': 25.1, 'dt_referencia': '2026-08-23T19:00:00Z'}
# {'regiao': 'Nordeste', 'cidade': 'ARACAJU', 'temperatura': 27.4, 'dt_referencia': '2026-08-23T19:00:00Z'}
# {'regiao': 'Nordeste', 'cidade': 'TERESINA', 'temperatura': 30.1, 'dt_referencia': '2026-08-23T21:00:00Z'}
# {'regiao': 'Nordeste', 'cidade': 'JOAO PESSOA', 'temperatura': 26.5, 'dt_referencia': '2026-08-23T21:00:00Z'}
# {'regiao': 'Centro-Oeste', 'cidade': 'CUIABA', 'temperatura': 35.8, 'dt_referencia': '2026-08-23T20:00:00Z'}
# {'regiao': 'Nordeste', 'cidade': 'NATAL', 'temperatura': 26.9, 'dt_referencia': '2026-08-23T21:00:00Z'}
# {'regiao': 'Norte', 'cidade': 'RIO BRANCO', 'temperatura': 33.2, 'dt_referencia': '2026-08-23T21:00:00Z'}
# {'regiao': 'Centro-Oeste', 'cidade': 'GOIANIA', 'temperatura': 30.3, 'dt_referencia': '2026-08-23T21:00:00Z'}
# {'regiao': 'Nordeste', 'cidade': 'RECIFE', 'temperatura': 26.7, 'dt_referencia': '2026-08-23T21:00:00Z'}
# {'regiao': 'Centro-Oeste', 'cidade': 'BRASILIA', 'temperatura': 27.2, 'dt_referencia': '2026-08-23T21:00:00Z'}
# {'regiao': 'Norte', 'cidade': 'BELEM', 'temperatura': 25.2, 'dt_referencia': '2026-08-23T21:00:00Z'}
# {'regiao': 'Nordeste', 'cidade': 'MACEIO', 'temperatura': 25.0, 'dt_referencia': '2026-08-23T21:00:00Z'}
# {'regiao': 'Norte', 'cidade': 'PALMAS', 'temperatura': 34.1, 'dt_referencia': '2026-08-23T21:00:00Z'}
# {'regiao': 'Nordeste', 'cidade': 'SALVADOR', 'temperatura': 24.6, 'dt_referencia': '2026-08-23T21:00:00Z'}
# {'regiao': 'Sudeste', 'cidade': 'VITORIA', 'temperatura': 19.3, 'dt_referencia': '2026-08-23T21:00:00Z'}
# {'regiao': 'Sudeste', 'cidade': 'RIO DE JANEIRO', 'temperatura': 21.1, 'dt_referencia': '2026-08-23T21:00:00Z'}
# {'regiao': 'Nordeste', 'cidade': 'SALVADOR', 'temperatura': 24.2, 'dt_referencia': '2026-08-23T21:00:00Z'}
# {'regiao': 'Sudeste', 'cidade': 'BELO HORIZONTE', 'temperatura': 23.9, 'dt_referencia': '2026-08-23T21:00:00Z'}
# {'regiao': 'Sudeste', 'cidade': 'RIO DE JANEIRO', 'temperatura': 21.5, 'dt_referencia': '2026-08-23T21:00:00Z'}
# {'regiao': 'Sudeste', 'cidade': 'SAO PAULO', 'temperatura': 17.1, 'dt_referencia': '2026-08-23T21:00:00Z'}
# {'regiao': 'Sul', 'cidade': 'PORTO ALEGRE', 'temperatura': 13.4, 'dt_referencia': '2026-08-23T21:00:00Z'}
# {'regiao': 'Centro-Oeste', 'cidade': 'CAMPO GRANDE', 'temperatura': 25.3, 'dt_referencia': '2026-08-23T21:00:00Z'}
# {'regiao': 'Sudeste', 'cidade': 'RIO DE JANEIRO', 'temperatura': 20.3, 'dt_referencia': '2026-08-23T21:00:00Z'}
# {'regiao': 'Sudeste', 'cidade': 'RIO DE JANEIRO', 'temperatura': 12.2, 'dt_referencia': '2026-08-23T21:00:00Z'}
# {'regiao': 'Sul', 'cidade': 'CURITIBA', 'temperatura': 15.1, 'dt_referencia': '2026-08-23T21:00:00Z'}
# {'regiao': 'Sudeste', 'cidade': 'VITORIA', 'temperatura': 23.0, 'dt_referencia': '2026-08-23T21:00:00Z'}
# {'regiao': 'Centro-Oeste', 'cidade': 'BRASILIA', 'temperatura': 30.9, 'dt_referencia': '2026-08-23T17:00:00Z'}
# {'regiao': 'Norte', 'cidade': 'BELEM', 'temperatura': 33.1, 'dt_referencia': '2026-08-23T17:00:00Z'}
# {'regiao': 'Nordeste', 'cidade': 'RECIFE', 'temperatura': 28.8, 'dt_referencia': '2026-08-23T17:00:00Z'}
# {'regiao': 'Norte', 'cidade': 'RIO BRANCO', 'temperatura': 32.7, 'dt_referencia': '2026-08-23T17:00:00Z'}
# {'regiao': 'Centro-Oeste', 'cidade': 'GOIANIA', 'temperatura': 34.1, 'dt_referencia': '2026-08-23T17:00:00Z'}
# {'regiao': 'Nordeste', 'cidade': 'MACEIO', 'temperatura': 28.6, 'dt_referencia': '2026-08-23T17:00:00Z'}
# {'regiao': 'Nordeste', 'cidade': 'NATAL', 'temperatura': 28.3, 'dt_referencia': '2026-08-23T17:00:00Z'}
# {'regiao': 'Norte', 'cidade': 'PALMAS', 'temperatura': 37.6, 'dt_referencia': '2026-08-23T17:00:00Z'}
# {'regiao': 'Nordeste', 'cidade': 'TERESINA', 'temperatura': 36.7, 'dt_referencia': '2026-08-23T17:00:00Z'}
# {'regiao': 'Nordeste', 'cidade': 'JOAO PESSOA', 'temperatura': 29.3, 'dt_referencia': '2026-08-23T17:00:00Z'}
# {'regiao': 'Centro-Oeste', 'cidade': 'BRASILIA', 'temperatura': 31.3, 'dt_referencia': '2026-08-23T18:00:00Z'}
# {'regiao': 'Norte', 'cidade': 'BELEM', 'temperatura': 32.8, 'dt_referencia': '2026-08-23T18:00:00Z'}
# {'regiao': 'Nordeste', 'cidade': 'RECIFE', 'temperatura': 28.2, 'dt_referencia': '2026-08-23T18:00:00Z'}
# {'regiao': 'Norte', 'cidade': 'RIO BRANCO', 'temperatura': 33.6, 'dt_referencia': '2026-08-23T18:00:00Z'}
# {'regiao': 'Centro-Oeste', 'cidade': 'GOIANIA', 'temperatura': 33.9, 'dt_referencia': '2026-08-23T18:00:00Z'}
# {'regiao': 'Nordeste', 'cidade': 'MACEIO', 'temperatura': 28.3, 'dt_referencia': '2026-08-23T18:00:00Z'}
# {'regiao': 'Nordeste', 'cidade': 'NATAL', 'temperatura': 28.4, 'dt_referencia': '2026-08-23T18:00:00Z'}
# {'regiao': 'Norte', 'cidade': 'PALMAS', 'temperatura': 37.9, 'dt_referencia': '2026-08-23T18:00:00Z'}
# {'regiao': 'Nordeste', 'cidade': 'TERESINA', 'temperatura': 37.2, 'dt_referencia': '2026-08-23T18:00:00Z'}
# {'regiao': 'Centro-Oeste', 'cidade': 'CUIABA', 'temperatura': 35.1, 'dt_referencia': '2026-08-23T17:00:00Z'}
# {'regiao': 'Nordeste', 'cidade': 'JOAO PESSOA', 'temperatura': 29.0, 'dt_referencia': '2026-08-23T18:00:00Z'}
# {'regiao': 'Sudeste', 'cidade': 'BELO HORIZONTE', 'temperatura': 25.5, 'dt_referencia': '2026-08-23T18:00:00Z'}
# {'regiao': 'Nordeste', 'cidade': 'ARACAJU', 'temperatura': 25.3, 'dt_referencia': '2026-08-23T21:00:00Z'}
# {'regiao': 'Sudeste', 'cidade': 'BELO HORIZONTE', 'temperatura': 20.5, 'dt_referencia': '2026-08-23T21:00:00Z'}
# {'regiao': 'Sul', 'cidade': 'CURITIBA', 'temperatura': 11.9, 'dt_referencia': '2026-08-23T21:00:00Z'}
# {'regiao': 'Nordeste', 'cidade': 'SALVADOR', 'temperatura': 28.5, 'dt_referencia': '2026-08-23T17:00:00Z'}
# {'regiao': 'Sudeste', 'cidade': 'VITORIA', 'temperatura': 10.8, 'dt_referencia': '2026-08-23T17:00:00Z'}
# {'regiao': 'Sul', 'cidade': 'PORTO ALEGRE', 'temperatura': 15.6, 'dt_referencia': '2026-08-23T17:00:00Z'}
# {'regiao': 'Norte', 'cidade': 'MACAPA', 'temperatura': 32.1, 'dt_referencia': '2026-08-23T17:00:00Z'}
# {'regiao': 'Norte', 'cidade': 'MANAUS', 'temperatura': 32.9, 'dt_referencia': '2026-08-23T17:00:00Z'}
# {'regiao': 'Sudeste', 'cidade': 'SAO PAULO', 'temperatura': 20.7, 'dt_referencia': '2026-08-23T17:00:00Z'}
# {'regiao': 'Sudeste', 'cidade': 'VITORIA', 'temperatura': 10.4, 'dt_referencia': '2026-08-23T18:00:00Z'}
# {'regiao': 'Sul', 'cidade': 'PORTO ALEGRE', 'temperatura': 15.9, 'dt_referencia': '2026-08-23T18:00:00Z'}
# {'regiao': 'Sul', 'cidade': 'CURITIBA', 'temperatura': 15.2, 'dt_referencia': '2026-08-23T18:00:00Z'}
# {'regiao': 'Norte', 'cidade': 'MACAPA', 'temperatura': 32.4, 'dt_referencia': '2026-08-23T18:00:00Z'}
# {'regiao': 'Sudeste', 'cidade': 'SAO PAULO', 'temperatura': 24.1, 'dt_referencia': '2026-08-23T18:00:00Z'}
# {'regiao': 'Centro-Oeste', 'cidade': 'BRASILIA', 'temperatura': 30.9, 'dt_referencia': '2026-08-23T18:00:00Z'}
# {'regiao': 'Sudeste', 'cidade': 'SAO PAULO', 'temperatura': 21.6, 'dt_referencia': '2026-08-23T18:00:00Z'}
# {'regiao': 'Centro-Oeste', 'cidade': 'GOIANIA', 'temperatura': 35.1, 'dt_referencia': '2026-08-23T18:00:00Z'}
# {'regiao': 'Nordeste', 'cidade': 'SALVADOR', 'temperatura': 27.7, 'dt_referencia': '2026-08-23T18:00:00Z'}
# {'regiao': 'Nordeste', 'cidade': 'NATAL', 'temperatura': 29.3, 'dt_referencia': '2026-08-23T18:00:00Z'}
# {'regiao': 'Norte', 'cidade': 'PORTO VELHO', 'temperatura': 34.4, 'dt_referencia': '2026-08-23T18:00:00Z'}
# {'regiao': 'Nordeste', 'cidade': 'RECIFE', 'temperatura': 28.3, 'dt_referencia': '2026-08-23T18:00:00Z'}
# {'regiao': 'Nordeste', 'cidade': 'JOAO PESSOA', 'temperatura': 28.2, 'dt_referencia': '2026-08-23T18:00:00Z'}
# {'regiao': 'Centro-Oeste', 'cidade': 'GOIANIA', 'temperatura': 34.1, 'dt_referencia': '2026-08-23T18:00:00Z'}
# {'regiao': 'Norte', 'cidade': 'PALMAS', 'temperatura': 37.3, 'dt_referencia': '2026-08-23T18:00:00Z'}
# {'regiao': 'Nordeste', 'cidade': 'ARACAJU', 'temperatura': 27.5, 'dt_referencia': '2026-08-23T18:00:00Z'}
# {'regiao': 'Sudeste', 'cidade': 'RIO DE JANEIRO', 'temperatura': 22.0, 'dt_referencia': '2026-08-23T18:00:00Z'}
# {'regiao': 'Sudeste', 'cidade': 'BELO HORIZONTE', 'temperatura': 27.9, 'dt_referencia': '2026-08-23T18:00:00Z'}
# {'regiao': 'Sudeste', 'cidade': 'SAO PAULO', 'temperatura': 16.5, 'dt_referencia': '2026-08-23T22:00:00Z'}
# {'regiao': 'Centro-Oeste', 'cidade': 'CAMPO GRANDE', 'temperatura': 23.6, 'dt_referencia': '2026-08-23T22:00:00Z'}
# {'regiao': 'Sudeste', 'cidade': 'BELO HORIZONTE', 'temperatura': 19.2, 'dt_referencia': '2026-08-23T22:00:00Z'}
# {'regiao': 'Nordeste', 'cidade': 'ARACAJU', 'temperatura': 23.0, 'dt_referencia': '2026-08-23T22:00:00Z'}
# {'regiao': 'Sudeste', 'cidade': 'BELO HORIZONTE', 'temperatura': 24.3, 'dt_referencia': '2026-08-23T21:00:00Z'}
# {'regiao': 'Norte', 'cidade': 'PORTO VELHO', 'temperatura': 32.0, 'dt_referencia': '2026-08-23T22:00:00Z'}
# {'regiao': 'Sudeste', 'cidade': 'SAO PAULO', 'temperatura': 15.0, 'dt_referencia': '2026-08-23T22:00:00Z'}
# {'regiao': 'Nordeste', 'cidade': 'SALVADOR', 'temperatura': 23.4, 'dt_referencia': '2026-08-23T22:00:00Z'}
# {'regiao': 'Sudeste', 'cidade': 'RIO DE JANEIRO', 'temperatura': 21.0, 'dt_referencia': '2026-08-23T22:00:00Z'}
# {'regiao': 'Sudeste', 'cidade': 'BELO HORIZONTE', 'temperatura': 22.4, 'dt_referencia': '2026-08-23T22:00:00Z'}
# {'regiao': 'Sudeste', 'cidade': 'RIO DE JANEIRO', 'temperatura': 21.4, 'dt_referencia': '2026-08-23T22:00:00Z'}
# {'regiao': 'Sudeste', 'cidade': 'VITORIA', 'temperatura': 23.0, 'dt_referencia': '2026-08-23T22:00:00Z'}
# {'regiao': 'Sudeste', 'cidade': 'RIO DE JANEIRO', 'temperatura': 20.5, 'dt_referencia': '2026-08-23T22:00:00Z'}
# {'regiao': 'Sudeste', 'cidade': 'RIO DE JANEIRO', 'temperatura': 12.6, 'dt_referencia': '2026-08-23T22:00:00Z'}
# {'regiao': 'Nordeste', 'cidade': 'NATAL', 'temperatura': 31.9, 'dt_referencia': '2026-08-23T22:00:00Z'}
# {'regiao': 'Sul', 'cidade': 'CURITIBA', 'temperatura': 12.9, 'dt_referencia': '2026-08-23T22:00:00Z'}
# {'regiao': 'Sul', 'cidade': 'PORTO ALEGRE', 'temperatura': 11.6, 'dt_referencia': '2026-08-23T22:00:00Z'}
# {'regiao': 'Nordeste', 'cidade': 'SALVADOR', 'temperatura': 28.8, 'dt_referencia': '2026-08-23T17:00:00Z'}
# {'regiao': 'Sudeste', 'cidade': 'RIO DE JANEIRO', 'temperatura': 21.6, 'dt_referencia': '2026-08-23T17:00:00Z'}
# {'regiao': 'Sudeste', 'cidade': 'VITORIA', 'temperatura': 25.4, 'dt_referencia': '2026-08-23T17:00:00Z'}
# {'regiao': 'Sudeste', 'cidade': 'RIO DE JANEIRO', 'temperatura': 23.6, 'dt_referencia': '2026-08-23T17:00:00Z'}
# {'regiao': 'Sudeste', 'cidade': 'SAO PAULO', 'temperatura': 22.9, 'dt_referencia': '2026-08-23T17:00:00Z'}
# {'regiao': 'Sudeste', 'cidade': 'BELO HORIZONTE', 'temperatura': 27.3, 'dt_referencia': '2026-08-23T17:00:00Z'}
# {'regiao': 'Centro-Oeste', 'cidade': 'CAMPO GRANDE', 'temperatura': 28.0, 'dt_referencia': '2026-08-23T17:00:00Z'}
# {'regiao': 'Sul', 'cidade': 'PORTO ALEGRE', 'temperatura': 15.6, 'dt_referencia': '2026-08-23T17:00:00Z'}
# {'regiao': 'Sudeste', 'cidade': 'RIO DE JANEIRO', 'temperatura': 22.5, 'dt_referencia': '2026-08-23T17:00:00Z'}
# {'regiao': 'Sudeste', 'cidade': 'RIO DE JANEIRO', 'temperatura': 13.7, 'dt_referencia': '2026-08-23T17:00:00Z'}
# {'regiao': 'Sul', 'cidade': 'CURITIBA', 'temperatura': 19.9, 'dt_referencia': '2026-08-23T17:00:00Z'}
# {'regiao': 'Nordeste', 'cidade': 'ARACAJU', 'temperatura': 26.6, 'dt_referencia': '2026-08-23T17:00:00Z'}
# {'regiao': 'Sudeste', 'cidade': 'RIO DE JANEIRO', 'temperatura': 21.1, 'dt_referencia': '2026-08-23T20:00:00Z'}
# {'regiao': 'Sudeste', 'cidade': 'RIO DE JANEIRO', 'temperatura': 12.4, 'dt_referencia': '2026-08-23T20:00:00Z'}
# {'regiao': 'Sudeste', 'cidade': 'SAO PAULO', 'temperatura': 19.2, 'dt_referencia': '2026-08-23T20:00:00Z'}
# {'regiao': 'Centro-Oeste', 'cidade': 'CAMPO GRANDE', 'temperatura': 27.7, 'dt_referencia': '2026-08-23T20:00:00Z'}
# {'regiao': 'Sudeste', 'cidade': 'BELO HORIZONTE', 'temperatura': 22.5, 'dt_referencia': '2026-08-23T20:00:00Z'}
# {'regiao': 'Norte', 'cidade': 'PORTO VELHO', 'temperatura': 34.9, 'dt_referencia': '2026-08-23T20:00:00Z'}
# {'regiao': 'Nordeste', 'cidade': 'ARACAJU', 'temperatura': 27.0, 'dt_referencia': '2026-08-23T20:00:00Z'}
# {'regiao': 'Nordeste', 'cidade': 'NATAL', 'temperatura': 35.4, 'dt_referencia': '2026-08-23T20:00:00Z'}
# {'regiao': 'Sul', 'cidade': 'PORTO ALEGRE', 'temperatura': 15.2, 'dt_referencia': '2026-08-23T20:00:00Z'}
# {'regiao': 'Sul', 'cidade': 'CURITIBA', 'temperatura': 19.8, 'dt_referencia': '2026-08-23T20:00:00Z'}
# {'regiao': 'Norte', 'cidade': 'PORTO VELHO', 'temperatura': 34.1, 'dt_referencia': '2026-08-23T21:00:00Z'}
# {'regiao': 'Nordeste', 'cidade': 'NATAL', 'temperatura': 33.9, 'dt_referencia': '2026-08-23T21:00:00Z'}
# {'regiao': 'Sudeste', 'cidade': 'VITORIA', 'temperatura': 8.3, 'dt_referencia': '2026-08-23T21:00:00Z'}
# {'regiao': 'Sudeste', 'cidade': 'SAO PAULO', 'temperatura': 15.6, 'dt_referencia': '2026-08-23T21:00:00Z'}
# {'regiao': 'Sul', 'cidade': 'PORTO ALEGRE', 'temperatura': 12.5, 'dt_referencia': '2026-08-23T21:00:00Z'}
# {'regiao': 'Norte', 'cidade': 'MANAUS', 'temperatura': 32.2, 'dt_referencia': '2026-08-23T21:00:00Z'}
# {'regiao': 'Norte', 'cidade': 'MACAPA', 'temperatura': 31.0, 'dt_referencia': '2026-08-23T21:00:00Z'}
# {'regiao': 'Nordeste', 'cidade': 'SAO LUIS', 'temperatura': 30.0, 'dt_referencia': '2026-08-23T21:00:00Z'}
# {'regiao': 'Sudeste', 'cidade': 'VITORIA', 'temperatura': 24.0, 'dt_referencia': '2026-08-23T17:00:00Z'}
# {'regiao': 'Sul', 'cidade': 'CURITIBA', 'temperatura': 14.7, 'dt_referencia': '2026-08-23T17:00:00Z'}
# {'regiao': 'Sudeste', 'cidade': 'BELO HORIZONTE', 'temperatura': 27.8, 'dt_referencia': '2026-08-23T17:00:00Z'}
# {'regiao': 'Sudeste', 'cidade': 'BELO HORIZONTE', 'temperatura': 25.9, 'dt_referencia': '2026-08-23T17:00:00Z'}
# {'regiao': 'Norte', 'cidade': 'PORTO VELHO', 'temperatura': 34.5, 'dt_referencia': '2026-08-23T17:00:00Z'}
# {'regiao': 'Nordeste', 'cidade': 'SAO LUIS', 'temperatura': 31.0, 'dt_referencia': '2026-08-23T17:00:00Z'}
# {'regiao': 'Sudeste', 'cidade': 'VITORIA', 'temperatura': 7.8, 'dt_referencia': '2026-08-23T22:00:00Z'}
# {'regiao': 'Sul', 'cidade': 'PORTO ALEGRE', 'temperatura': 11.6, 'dt_referencia': '2026-08-23T22:00:00Z'}
# {'regiao': 'Sul', 'cidade': 'CURITIBA', 'temperatura': 10.0, 'dt_referencia': '2026-08-23T22:00:00Z'}
# {'regiao': 'Sudeste', 'cidade': 'BELO HORIZONTE', 'temperatura': 22.9, 'dt_referencia': '2026-08-23T22:00:00Z'}
# {'regiao': 'Norte', 'cidade': 'MANAUS', 'temperatura': 31.4, 'dt_referencia': '2026-08-23T22:00:00Z'}
# {'regiao': 'Norte', 'cidade': 'MACAPA', 'temperatura': 30.2, 'dt_referencia': '2026-08-23T22:00:00Z'}
# {'regiao': 'Nordeste', 'cidade': 'SAO LUIS', 'temperatura': 26.7, 'dt_referencia': '2026-08-23T22:00:00Z'}
# {'regiao': 'Sul', 'cidade': 'CURITIBA', 'temperatura': 14.5, 'dt_referencia': '2026-08-23T20:00:00Z'}
# {'regiao': 'Sudeste', 'cidade': 'SAO PAULO', 'temperatura': 16.9, 'dt_referencia': '2026-08-23T20:00:00Z'}
# {'regiao': 'Sudeste', 'cidade': 'VITORIA', 'temperatura': 9.2, 'dt_referencia': '2026-08-23T20:00:00Z'}
# {'regiao': 'Sul', 'cidade': 'PORTO ALEGRE', 'temperatura': 14.3, 'dt_referencia': '2026-08-23T20:00:00Z'}
# {'regiao': 'Norte', 'cidade': 'MANAUS', 'temperatura': 33.2, 'dt_referencia': '2026-08-23T20:00:00Z'}
# {'regiao': 'Norte', 'cidade': 'MACAPA', 'temperatura': 32.2, 'dt_referencia': '2026-08-23T20:00:00Z'}
# {'regiao': 'Nordeste', 'cidade': 'SAO LUIS', 'temperatura': 31.7, 'dt_referencia': '2026-08-23T20:00:00Z'}
# {'regiao': 'Nordeste', 'cidade': 'NATAL', 'temperatura': 35.3, 'dt_referencia': '2026-08-23T17:00:00Z'}
# {'regiao': 'Sudeste', 'cidade': 'SAO PAULO', 'temperatura': 18.2, 'dt_referencia': '2026-08-23T19:00:00Z'}
# {'regiao': 'Norte', 'cidade': 'MANAUS', 'temperatura': 33.8, 'dt_referencia': '2026-08-23T19:00:00Z'}
# {'regiao': 'Norte', 'cidade': 'MACAPA', 'temperatura': 32.4, 'dt_referencia': '2026-08-23T19:00:00Z'}
# {'regiao': 'Nordeste', 'cidade': 'SAO LUIS', 'temperatura': 31.7, 'dt_referencia': '2026-08-23T19:00:00Z'}
# {'regiao': 'Nordeste', 'cidade': 'NATAL', 'temperatura': 28.3, 'dt_referencia': '2026-08-23T18:00:00Z'}
# {'regiao': 'Centro-Oeste', 'cidade': 'CUIABA', 'temperatura': 36.3, 'dt_referencia': '2026-08-23T19:00:00Z'}
# {'regiao': 'Centro-Oeste', 'cidade': 'BRASILIA', 'temperatura': 30.8, 'dt_referencia': '2026-08-23T20:00:00Z'}
# {'regiao': 'Nordeste', 'cidade': 'MACEIO', 'temperatura': 25.9, 'dt_referencia': '2026-08-23T20:00:00Z'}
# {'regiao': 'Norte', 'cidade': 'PALMAS', 'temperatura': 37.6, 'dt_referencia': '2026-08-23T20:00:00Z'}
# {'regiao': 'Nordeste', 'cidade': 'RECIFE', 'temperatura': 27.3, 'dt_referencia': '2026-08-23T20:00:00Z'}
# {'regiao': 'Centro-Oeste', 'cidade': 'GOIANIA', 'temperatura': 33.2, 'dt_referencia': '2026-08-23T20:00:00Z'}
# {'regiao': 'Nordeste', 'cidade': 'NATAL', 'temperatura': 27.2, 'dt_referencia': '2026-08-23T20:00:00Z'}
# {'regiao': 'Norte', 'cidade': 'BELEM', 'temperatura': 25.8, 'dt_referencia': '2026-08-23T20:00:00Z'}
# {'regiao': 'Centro-Oeste', 'cidade': 'BRASILIA', 'temperatura': 24.4, 'dt_referencia': '2026-08-23T22:00:00Z'}
# {'regiao': 'Norte', 'cidade': 'BELEM', 'temperatura': 25.7, 'dt_referencia': '2026-08-23T22:00:00Z'}
# {'regiao': 'Norte', 'cidade': 'RIO BRANCO', 'temperatura': 30.6, 'dt_referencia': '2026-08-23T22:00:00Z'}
# {'regiao': 'Nordeste', 'cidade': 'RECIFE', 'temperatura': 26.7, 'dt_referencia': '2026-08-23T22:00:00Z'}
# {'regiao': 'Centro-Oeste', 'cidade': 'GOIANIA', 'temperatura': 29.0, 'dt_referencia': '2026-08-23T22:00:00Z'}
# {'regiao': 'Nordeste', 'cidade': 'MACEIO', 'temperatura': 24.9, 'dt_referencia': '2026-08-23T22:00:00Z'}
# {'regiao': 'Nordeste', 'cidade': 'NATAL', 'temperatura': 26.6, 'dt_referencia': '2026-08-23T22:00:00Z'}
# {'regiao': 'Norte', 'cidade': 'PALMAS', 'temperatura': 31.2, 'dt_referencia': '2026-08-23T22:00:00Z'}
# {'regiao': 'Nordeste', 'cidade': 'TERESINA', 'temperatura': 30.1, 'dt_referencia': '2026-08-23T22:00:00Z'}
# {'regiao': 'Nordeste', 'cidade': 'JOAO PESSOA', 'temperatura': 26.2, 'dt_referencia': '2026-08-23T22:00:00Z'}
# {'regiao': 'Centro-Oeste', 'cidade': 'CUIABA', 'temperatura': 35.3, 'dt_referencia': '2026-08-23T21:00:00Z'}
# {'regiao': 'Nordeste', 'cidade': 'SALVADOR', 'temperatura': 24.2, 'dt_referencia': '2026-08-23T22:00:00Z'}
# {'regiao': 'Sudeste', 'cidade': 'VITORIA', 'temperatura': 18.8, 'dt_referencia': '2026-08-23T22:00:00Z'}
# {'regiao': 'Nordeste', 'cidade': 'SALVADOR', 'temperatura': 28.0, 'dt_referencia': '2026-08-23T18:00:00Z'}
# {'regiao': 'Sudeste', 'cidade': 'VITORIA', 'temperatura': 23.4, 'dt_referencia': '2026-08-23T18:00:00Z'}
# {'regiao': 'Nordeste', 'cidade': 'SALVADOR', 'temperatura': 28.2, 'dt_referencia': '2026-08-23T18:00:00Z'}
# {'regiao': 'Sudeste', 'cidade': 'RIO DE JANEIRO', 'temperatura': 22.1, 'dt_referencia': '2026-08-23T18:00:00Z'}
# {'regiao': 'Sudeste', 'cidade': 'VITORIA', 'temperatura': 25.4, 'dt_referencia': '2026-08-23T18:00:00Z'}
# {'regiao': 'Sudeste', 'cidade': 'RIO DE JANEIRO', 'temperatura': 22.6, 'dt_referencia': '2026-08-23T18:00:00Z'}
# {'regiao': 'Sudeste', 'cidade': 'SAO PAULO', 'temperatura': 23.0, 'dt_referencia': '2026-08-23T18:00:00Z'}
# {'regiao': 'Centro-Oeste', 'cidade': 'CAMPO GRANDE', 'temperatura': 28.6, 'dt_referencia': '2026-08-23T18:00:00Z'}
# {'regiao': 'Sudeste', 'cidade': 'RIO DE JANEIRO', 'temperatura': 21.8, 'dt_referencia': '2026-08-23T18:00:00Z'}
# {'regiao': 'Sudeste', 'cidade': 'RIO DE JANEIRO', 'temperatura': 13.0, 'dt_referencia': '2026-08-23T18:00:00Z'}
# {'regiao': 'Sudeste', 'cidade': 'BELO HORIZONTE', 'temperatura': 29.2, 'dt_referencia': '2026-08-23T18:00:00Z'}
# {'regiao': 'Nordeste', 'cidade': 'ARACAJU', 'temperatura': 27.9, 'dt_referencia': '2026-08-23T18:00:00Z'}
# {'regiao': 'Sul', 'cidade': 'PORTO ALEGRE', 'temperatura': 15.9, 'dt_referencia': '2026-08-23T18:00:00Z'}
# {'regiao': 'Sul', 'cidade': 'CURITIBA', 'temperatura': 20.0, 'dt_referencia': '2026-08-23T18:00:00Z'}
# {'regiao': 'Norte', 'cidade': 'PORTO VELHO', 'temperatura': 34.1, 'dt_referencia': '2026-08-23T18:00:00Z'}
# {'regiao': 'Sudeste', 'cidade': 'SAO PAULO', 'temperatura': 19.5, 'dt_referencia': '2026-08-23T18:00:00Z'}
# {'regiao': 'Nordeste', 'cidade': 'NATAL', 'temperatura': 35.5, 'dt_referencia': '2026-08-23T18:00:00Z'}
# {'regiao': 'Nordeste', 'cidade': 'JOAO PESSOA', 'temperatura': 27.1, 'dt_referencia': '2026-08-23T20:00:00Z'}
# {'regiao': 'Nordeste', 'cidade': 'TERESINA', 'temperatura': 36.1, 'dt_referencia': '2026-08-23T20:00:00Z'}
# {'regiao': 'Norte', 'cidade': 'RIO BRANCO', 'temperatura': 33.0, 'dt_referencia': '2026-08-23T20:00:00Z'}
# {'regiao': 'Nordeste', 'cidade': 'SALVADOR', 'temperatura': 25.0, 'dt_referencia': '2026-08-23T20:00:00Z'}
# {'regiao': 'Sudeste', 'cidade': 'VITORIA', 'temperatura': 21.7, 'dt_referencia': '2026-08-23T20:00:00Z'}
# {'regiao': 'Nordeste', 'cidade': 'SALVADOR', 'temperatura': 26.0, 'dt_referencia': '2026-08-23T20:00:00Z'}
# {'regiao': 'Sudeste', 'cidade': 'RIO DE JANEIRO', 'temperatura': 21.3, 'dt_referencia': '2026-08-23T20:00:00Z'}
# {'regiao': 'Sudeste', 'cidade': 'VITORIA', 'temperatura': 23.6, 'dt_referencia': '2026-08-23T20:00:00Z'}
# {'regiao': 'Sudeste', 'cidade': 'BELO HORIZONTE', 'temperatura': 25.6, 'dt_referencia': '2026-08-23T20:00:00Z'}
# {'regiao': 'Sudeste', 'cidade': 'RIO DE JANEIRO', 'temperatura': 21.8, 'dt_referencia': '2026-08-23T20:00:00Z'}
