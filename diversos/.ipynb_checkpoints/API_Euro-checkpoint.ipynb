# %%
import requests

from datetime import datetime, timedelta

# %%
import sys
import os

root = os.path.abspath(os.path.join(os.getcwd(), "../"))

if root not in sys.path:
    sys.path.insert(0, root)

print(root)
# Out:
# /home/hilaneto/Jhan/Desenvolvimento/Python/Projetos/AtualizaIndicador

# %%
# Datas -------------------------------------------------------
hoje = datetime.now()
data_inicial = (hoje - timedelta(days=62)).strftime("%d/%m/%Y")
data_final = hoje.strftime("%d/%m/%Y")

hoje = datetime.now().strftime("%m-%d-%Y")

print(f"Período: {data_inicial} até {data_final}")

print(hoje)

# %% [markdown]
# ##### Busca Euro - Código VSCode - Awesomeapi

# %%
import os
import requests
from dotenv import load_dotenv

load_dotenv()
AWESOME_API_KEY = os.getenv("AWESOME_API_KEY")

url = "https://economia.awesomeapi.com.br/json/last/EUR-BRL"
headers = {"x-api-key": AWESOME_API_KEY}
resposta = requests.get(url, headers=headers, timeout=10)
resposta.raise_for_status()
dolar = resposta.json()["EURBRL"]

print(dolar)
print("Compra:", dolar["bid"])
print("Venda:", dolar["ask"])
print("Variação:", dolar["pctChange"])
print("Data/hora:", dolar["create_date"])
# Out:
# {'code': 'EUR', 'codein': 'BRL', 'name': 'Euro/Real Brasileiro', 'high': '6.0835', 'low': '5.9968', 'varBid': '-0.0692', 'pctChange': '-1.140036', 'bid': '6.0008', 'ask': '6.0028', 'timestamp': '1787347196', 'create_date': '2026-08-21 18:19:56'}
# Compra: 6.0008
# Venda: 6.0028
# Variação: -1.140036
# Data/hora: 2026-08-21 18:19:56

# %% [markdown]
# ##### Busca Dolar - AwesomeApi

# %%
from database.conexao import conectar
from indicadores.euro import Euro

dados = Euro.buscar()

print(dados)
# Out:
# {'EURBRL': {'code': 'EUR', 'codein': 'BRL', 'name': 'Euro/Real Brasileiro', 'high': '6.0835', 'low': '5.9968', 'varBid': '-0.0692', 'pctChange': '-1.140036', 'bid': '6.0008', 'ask': '6.0028', 'timestamp': '1787347196', 'create_date': '2026-08-21 18:19:56'}}

# %% [markdown]
# ##### Tratar Dados

# %%
from database.conexao import conectar
from indicadores.euro import Euro

aa = Euro.tratar_dados(dados)

print(aa)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 4
#       1 from database.conexao import conectar
#       2 from indicadores.euro import Euro
#       3
# ----> 4 aa = Euro.tratar_dados(dados)
#       5
#       6 print(aa)
#       7
#
# File ~/Jhan/Desenvolvimento/Python/Projetos/AtualizaIndicador/indicadores/euro.py:34, in Euro.tratar_dados(dados_api)
#      32 @staticmethod
#      33 def tratar_dados(dados_api):
# ---> 34     euro = dados_api["USDBRL"]
#      35     return {"valor": Decimal(euro["bid"]),
#      36             "status": True,
#      37             "moeda": str(euro["code"]),
#    (...)     41             "dt_atualizacao": datetime.now()
#      42             }
#
# KeyError: 'USDBRL'

# %% [markdown]
# ##### Atualizar tb_dolar no Banco

# %%
from database.conexao import conectar
from indicadores.dolar import Dolar

aa = Dolar.atualizar_dolar()

# %% [markdown]
# #### API Banco Central

# %%
# resposta = requests.get("https://olinda.bcb.gov.br/olinda/servico/PTAX/versao/v1/odata/CotacaoMoedaDia(moeda='USD',dataCotacao='08-21-2026')")

hoje = datetime.now().strftime("%m-%d-%Y")

url = ("https://olinda.bcb.gov.br/olinda/servico/PTAX/versao/v1/odata/CotacaoMoedaDia(moeda=@moeda,dataCotacao=@dataCotacao)")

parametros = { "@moeda": "'USD'", "@dataCotacao": f"'{hoje}'", "$format": "json" }

resposta = requests.get( url, params=parametros, timeout=10 )

resposta.raise_for_status()

dados = resposta.json()

dados
