# %%
import requests

from datetime import datetime, timedelta

# %%
import sys
import os

root = os.path.abspath(os.path.join(os.getcwd(), "../"))

if root not in sys.path:
    sys.path.insert(0, root)

print(root)
# Out:
# /home/hilaneto/Jhan/Trabalho/python/projetos/AtualizaIndicador

# %%
from database.conexao import conectar
from indicadores.ibovespa import Ibovespa

dados = Ibovespa.buscar()

print(dados)
# Out:
# {'results': [{'symbol': '^BVSP', 'shortName': 'IBOVESPA', 'longName': 'IBOVESPA', 'currency': 'BRL', 'regularMarketPrice': 185739.19, 'regularMarketDayHigh': 187320.95, 'regularMarketDayLow': 183813.36, 'regularMarketDayRange': '183813.36 - 187320.95', 'regularMarketChange': -1467.7, 'regularMarketChangePercent': -0.78, 'regularMarketTime': '2026-09-14T18:52:50.000Z', 'marketCap': None, 'regularMarketVolume': 0, 'regularMarketPreviousClose': 187206.89, 'regularMarketOpen': 185739.19, 'fiftyTwoWeekRange': '140231 - 199355', 'fiftyTwoWeekLow': 140231, 'fiftyTwoWeekHigh': 199355, 'priceEarnings': None, 'earningsPerShare': None, 'logourl': 'https://icons.brapi.dev/icons/^BVSP.svg'}], 'requestedAt': '2026-09-14T18:53:19.046Z', 'took': 1}

# %%
from database.conexao import conectar
from indicadores.ibovespa import Ibovespa

dados = Ibovespa.buscar()

massa = Ibovespa.tratar_dados(dados)

print(massa)
# Out:
# {'pontos': Decimal('185519.06'), 'variacao': Decimal('-0.9'), 'variacao_pontos': Decimal('-1687.83'), 'abertura': Decimal('185519.06'), 'maxima': Decimal('187320.95'), 'minima': Decimal('183813.36'), 'fechamento_anterior': Decimal('187206.89'), 'status': True, 'dt_referencia': datetime.datetime(2026, 9, 14, 16, 34, 2, tzinfo=zoneinfo.ZoneInfo(key='America/Sao_Paulo')), 'dt_atualizacao': datetime.datetime(2026, 9, 14, 16, 34, 42, 153690)}

# %%
from database.conexao import conectar
from indicadores.ibovespa import Ibovespa

dados = Ibovespa.atualizar_ibovespa()

# %%
import requests

url = "https://brapi.dev/api/quote/list"

response = requests.request("GET", url)

print(response.text)
# Out:
# {"indexes":[{"stock":"^BVSP","name":"IBOVESPA"},{"stock":"IFIX.SA","name":"Índice de Fundos Imobiliários"}],"stocks":[{"stock":"FNOR11","name":"FNOR11","close":0.51,"change":0,"volume":203488000,"market_cap":null,"logo":"https://icons.brapi.dev/icons/BRAPI.svg","sector":null,"subsector":null,"type":"fund","subType":"etf"},{"stock":"B3SA3","name":"B3 S.A. - BRASIL. BOLSA. BALCÃO","close":17.38,"change":0.58,"volume":27866800,"market_cap":83954765211,"logo":"https://icons.brapi.dev/icons/B3SA3.svg","sector":"Finance","subsector":"Dados Financeiros e Bolsas de Valores","type":"stock","subType":"stock"},{"stock":"PETR4","name":"PETROLEO BRASILEIRO S.A. PETROBRAS","close":48.87,"change":-0.27,"volume":25240200,"market_cap":666002537664,"logo":"https://icons.brapi.dev/icons/PETR4.svg","sector":"Energy Minerals","subsector":"Petróleo e Gás Integrado","type":"stock","subType":"stock"},{"stock":"BBAS3","name":"BCO BRASIL S.A.","close":22.17,"change":-1.42,"volume":23766000,"market_cap":128616
# ...

# %%
import requests

url = "https://brapi.dev/api/quote/%5EBVSP"
headers = {"Authorization": "Bearer nBBWGiGD5RfKbiHxK1ewX5"}

response = requests.get(url, headers=headers)
print(response.text)

# %%
from pathlib import Path

print(Path.cwd())
print(Path(".env").exists())
